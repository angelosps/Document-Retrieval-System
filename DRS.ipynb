# %% [markdown]
# # **Document Retrieval System 🗂️**
#
# We are going to implement a document retrieval system to return titles and the relevant passages of scientific papers containing the answer to a given user question. Through the implementation of the document retrieval system I'm going to experiment with different models for sentence embeddings.
#
# Dataset: [COVID-19 Open Research Dataset (CORD-19)](https://www.semanticscholar.org/cord19).
#
# We are going to use the articles in the folder `comm_use_subset` of the [*first version (2020-03-13)*](https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/historical_releases/cord-19_2020-03-13.tar.gz) of CORD-19.

# %% [markdown]
# **Some essential imports**

# %%
import os, json
import pandas as pd
import numpy as np
import nltk
import ssl
import re
import torch
from nltk.tokenize import sent_tokenize
from sklearn.metrics.pairwise import cosine_similarity
import time

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### **Install the sentence transformers 🤗**

# %%
# !pip install -U sentence-transformers

from sentence_transformers import SentenceTransformer, util
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 3.5 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.11.3-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 10.7 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 55.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.9.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.2 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.0.19-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.8.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 57.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 58.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=6e2fbd1ea790de1aabc047370b33f9b353a5ba63fd62e5d20570e74e91898b76
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.19 pyyaml-6.0 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.11.3

# %% [markdown]
# ### **Download the CORD-19 dataset ⬇️**
#
# Get the first version (2020-03-13) of CORD-19 and extract the folder `comm_use_subset`.

# %%
# !wget -nc https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/historical_releases/cord-19_2020-03-13.tar.gz
# Out:
# --2021-10-14 06:20:35--  https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/historical_releases/cord-19_2020-03-13.tar.gz
# Resolving ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com (ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com)... 52.218.181.153
# Connecting to ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com (ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com)|52.218.181.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278921140 (266M) [application/x-tar]
# Saving to: ‘cord-19_2020-03-13.tar.gz’
#
# cord-19_2020-03-13. 100%[===================>] 266.00M  23.0MB/s    in 11s
#
# 2021-10-14 06:20:46 (24.2 MB/s) - ‘cord-19_2020-03-13.tar.gz’ saved [278921140/278921140]

# %%
# !tar -xvf cord-19_2020-03-13.tar.gz
# !tar -xvf 2020-03-13/comm_use_subset.tar.gz
# Out:
# 2021-10-11/changelog
# 2021-10-11/cord_19_embeddings.tar.gz
# ^C
# tar: 2021-10-11/comm_use_subset.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %% [markdown]
# ### **Data preprocessing 💽**
#
# We get the *title, abstract* and *text* from each article.

# %% [markdown]
# #### **Keep the useful data from articles 📁**

# %%
# this finds our json files
path_to_json = 'comm_use_subset/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# here I define my pandas Dataframe with the columns I want to get from the json
jsons_data = pd.DataFrame(columns=['title', 'abstract', 'text'])

# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
  with open(os.path.join(path_to_json, js)) as json_file:
    json_text = json.load(json_file)
    title = json_text['metadata']['title']
    #if not title:
    #  title = 'Article without title'
    
    all_abstract = ''
    if json_text['abstract']:
      for abstract in json_text['abstract']:
        all_abstract += abstract['text']
    
    #if not all_abstract:
    #  all_abstract = 'No abstract'
    
    all_text = ''
    for text in json_text['body_text']:
      all_text += text['text']
    
    #if not all_text:
    #  all_text = 'No text'
        
    jsons_data.loc[index] = [title, all_abstract, all_text]
        
# now that we have the pertinent json data in our DataFrame let's look at it
print(jsons_data)
# Out:
#                                                   title  ...                                               text
# 0     Hazard Analysis of Critical Control Points Ass...  ...  Since 1980, on average one new emerging infect...
# 1     Gene expression patterns induced at different ...  ...  Human rhinovirus (HRV), a non-segmented positi...
# 2     Comparison of Influenza Epidemiological and Vi...  ...  Influenza virus is estimated to cause 3 to 5 m...
# 3     expression cloning and production of human hea...  ...  FIgURe 1 | Schematic representation of the pro...
# 4     STATISTICS-BASED PREDICTIONS OF CORONAVIRUS EP...  ...  Here, we consider the development of an epidem...
# ...                                                 ...  ...                                                ...
# 8995  Comprehensive Genomic Characterization Analysi...  ...  Long non-coding RNAs (lncRNAs), which are tran...
# 8996       Emerging Microbes & Infections (2017) 6, e14  ...  The outbreak of severe acute respiratory syndr...
# 8997  Open Access Epidemiology and clinical outcome ...  ...  Respiratory viruses represent an important rol...
# 8998  Ifitm3 Limits the Severity of Acute Influenza ...  ...  The interferon-induced transmembrane (IFITM) p...
# 8999  ): e38241. of China (2012ZX10002-004), Nationa...  ...  Not all viruses are equally prone to recombina...
#
# [9000 rows x 3 columns]

# %%
print(jsons_data.head())
# Out:
#                                                title  ...                                               text
# 0  Hazard Analysis of Critical Control Points Ass...  ...  Since 1980, on average one new emerging infect...
# 1  Gene expression patterns induced at different ...  ...  Human rhinovirus (HRV), a non-segmented positi...
# 2  Comparison of Influenza Epidemiological and Vi...  ...  Influenza virus is estimated to cause 3 to 5 m...
# 3  expression cloning and production of human hea...  ...  FIgURe 1 | Schematic representation of the pro...
# 4  STATISTICS-BASED PREDICTIONS OF CORONAVIRUS EP...  ...  Here, we consider the development of an epidem...
#
# [5 rows x 3 columns]

# %% [markdown]
# #### **Data cleaning 🧹**

# %%
def clean_data(sentences, MAX_SEQ_LEN):
  # Tokenize the passages into sentences
  sentences = sent_tokenize(sentences, language='english')
  # Keep only the sentences with more than 10 words and less than MAX_SEQ_LEN+1 words
  sentences = [sentence for sentence in sentences if len(sentence.split()) > 15 and len(sentence.split()) <= MAX_SEQ_LEN]

  return sentences

# %%
# Checking on the cleaned data
print(clean_data(jsons_data['abstract'][0], 256))
# Out:
# ['Highly pathogenic avian influenza virus (HPAI) strain H5N1 has had direct and indirect economic impacts arising from direct mortality and control programmes in over 50 countries reporting poultry outbreaks.', 'HPAI H5N1 is now reported as the most widespread and expensive zoonotic disease recorded and continues to pose a global health threat.', 'The aim of this research was to assess the potential of utilising Hazard Analysis of Critical Control Points (HACCP) assessments in providing a framework for a rapid response to emerging infectious disease outbreaks.', 'This novel approach applies a scientific process, widely used in food production systems, to assess risks related to a specific emerging health threat within a known zoonotic disease hotspot.', "We conducted a HACCP assessment for HPAI viruses within Vietnam's domestic poultry trade and relate our findings to the existing literature.", "Our HACCP assessment identified poultry flock isolation, transportation, slaughter, preparation and consumption as critical control points for Vietnam's domestic poultry trade.", 'Introduction of the preventative measures highlighted through this HACCP evaluation would reduce the risks posed by HPAI viruses and pressure on the national economy.', 'We conclude that this HACCP assessment provides compelling evidence for the future potential that HACCP analyses could play in initiating a rapid response to emerging infectious diseases.']

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Working on {device}')
# Out:
# Working on cuda

# %% [markdown]
# ### **Questions definition❓**

# %%
questions = ['What are the coronaviruses?', 
            'What was discovered in Wuhuan in December 2019?',
            'What is Coronovirus Disease 2019?',
            'What is COVID-19?',
            'What is caused by SARS-COV2?',
            'How is COVID-19 spread?',
            'Where was COVID-19 discovered?',
            'How many deaths were caused by COVID-19?',
            'Does wearing a mask prevent the spread of COVID-19?']

# %% [markdown]
# ### **Models definition 🤖**
#
# I am defining and listing the models from sentence transformers according to their performance (ranked on Semantic Search) from best to worst according to [ranking from SBERT](https://www.sbert.net/_static/html/models_en_sentence_embeddings.html).
#
# 1. `multi-qa-mpnet-base-dot-v1`
# 2. `all-mpnet-base-v2`
# 3. `all-roberta-large-v1`
# 4. `msmarco-bert-base-dot-v5`
# 5. `msmarco-distilbert-dot-v5`

# %%
model_1 = SentenceTransformer('multi-qa-mpnet-base-dot-v1').to(device) 
model_2 = SentenceTransformer('all-mpnet-base-v2').to(device) 
model_3 = SentenceTransformer('all-roberta-large-v1').to(device) 
model_4 = SentenceTransformer('msmarco-bert-base-dot-v5').to(device) 
model_5 = SentenceTransformer('msmarco-distilbert-dot-v5').to(device)
# Out:
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/25.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/650 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/328 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/461 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/546 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Declaring the models' names for printing purposes
model_names = {
  model_1 : 'multi-qa-mpnet-base-dot-v1',
  model_2 : 'all-mpnet-base-v2',
  model_3 : 'all-roberta-large-v1',
  model_4 : 'msmarco-bert-base-dot-v5',
  model_5 : 'msmarco-distilbert-dot-v5'
}

# %%
# Define the maximum sequence length of input for each model as stated in their documentation 
model_max_seq_len = {
  model_1 : 512,
  model_2 : 384,
  model_3 : 256,
  model_4 : 512,
  model_5 : 512,
}

# %% [markdown]
# ### **Search function 🔍**

# %%
def search(model, N_SAMPLES = None):
  best_scores = [-100 for i in range(len(questions))]
  best_titles = ['' for i in range(len(questions))]
  best_answers = ['' for i in range(len(questions))]

  if N_SAMPLES != None:
    sample = jsons_data.sample(n=N_SAMPLES, random_state=123)
  else:
    sample = jsons_data

  print(f'Running the `{model_names[model]}` for {len(sample.index)} documents\n')
  
  questions_embeddings = model.encode(questions)
  MAX_SEQ_LEN = model_max_seq_len[model]

  start_time = time.time()
  counter = 0
  for index, row in sample.iterrows():
    counter += 1
    abstract_sentences = row['abstract']
    text_sentences = row['text']
    data = abstract_sentences + text_sentences
    data = clean_data(data, MAX_SEQ_LEN)

    if not row['title']:
      print(f'Document {counter-1} has no title. Proceeding..')
      continue
    if not data:
      print(f'No data on document {counter-1}. Proceeding..')
      continue

    data_embeddings = model.encode(data)

    for q_idx, question_embeddings in enumerate(questions_embeddings):
      
      scores = util.dot_score(question_embeddings, data_embeddings)[0].cpu().tolist()

      # Combine docs & scores
      doc_score_pairs = list(zip(data, scores))

      # Sort by decreasing score
      doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)

      score = doc_score_pairs[0][1]
      answer = doc_score_pairs[0][0]

      if score > best_scores[q_idx]:
        best_scores[q_idx]  = score
        best_titles[q_idx]  = row['title']
        best_answers[q_idx] = answer
            
    print(f'Document {counter}/{len(sample.index)}')
      
  end_time = time.time()
  elapsed_time = end_time - start_time
  elapsed_mins = int(elapsed_time / 60)
  elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
  print(f'Elapsed time: {elapsed_mins}m {elapsed_secs}s')

  return best_scores, best_titles, best_answers

# %%
# Check what GPU we are assigned
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-6ee0d770-3b4c-534f-6981-2d0748cc6745)

# %% [markdown]
# ### **Run the models 🏃‍♂️**
#
# Choose between the following models:
#
# 1. `model_1` : `multi-qa-mpnet-base-dot-v1`
# 2. `model_2` : `all-mpnet-base-v2`
# 3. `model_3` : `all-roberta-large-v1`
# 4. `model_4` : `msmarco-bert-base-dot-v5`
# 5. `model_5` : `msmarco-distilbert-dot-v5`

# %%
# SEARCH!
scores, titles, answers = search(model_1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Document 4002/9000
# Document 4003/9000
# Document 4004/9000
# Document 4005/9000
# Document 4006/9000
# Document 4006 has no title. Proceeding..
# Document 4008/9000
# Document 4009/9000
# Document 4010/9000
# Document 4011/9000
# Document 4012/9000
# Document 4013/9000
# Document 4014/9000
# Document 4015/9000
# Document 4016/9000
# Document 4017/9000
# Document 4018/9000
# Document 4019/9000
# Document 4020/9000
# Document 4021/9000
# Document 4021 has no title. Proceeding..
# Document 4023/9000
# Document 4024/9000
# Document 4025/9000
# Document 4026/9000
# Document 4027/9000
# Document 4028/9000
# Document 4029/9000
# Document 4030/9000
# Document 4031/9000
# Document 4032/9000
# Document 4033/9000
# Document 4034/9000
# Document 4035/9000
# Document 4036/9000
# Document 4037/9000
# Document 4038/9000
# Document 4039/9000
# Document 4040/9000
# Document 4041/9000
# Document 4042/9000
# Document 4043/9000
# Document 4044/9000
# Document 4044 has no title. Proceeding..
# Document 4046/9000
# Document 4047/9000
# Document 4048/9000
# Document 4049/9000
# Document 4050/9000
# Document 4051/9000
# Document 4052/9000
# Document 4053/9000
# Document 4054/9000
# Document 4055/9000
# Document 4056/9000
# Document 4057/9000
# Document 4058/9000
# Document 4059/9000
# Document 4060/9000
# Document 4061/9000
# Document 4062/9000
# Document 4063/9000
# Document 4064/9000
# Document 4064 has no title. Proceeding..
# Document 4066/9000
# Document 4067/9000
# Document 4068/9000
# Document 4069/9000
# Document 4070/9000
# Document 4071/9000
# Document 4072/9000
# Document 4073/9000
# Document 4074/9000
# Document 4075/9000
# Document 4076/9000
# Document 4077/9000
# Document 4078/9000
# Document 4079/9000
# Document 4080/9000
# Document 4081/9000
# Document 4082/9000
# Document 4083/9000
# Document 4084/9000
# Document 4085/9000
# Document 4086/9000
# Document 4087/9000
# Document 4088/9000
# Document 4089/9000
# Document 4090/9000
# Document 4091/9000
# Document 4092/9000
# Document 4093/9000
# Document 4094/9000
# Document 4095/9000
# Document 4096/9000
# Document 4097/9000
# Document 4098/9000
# Document 4099/9000
# Document 4100/9000
# Document 4101/9000
# Document 4102/9000
# Document 4103/9000
# Document 4104/9000
# Document 4105/9000
# Document 4106/9000
# Document 4107/9000
# Document 4108/9000
# Document 4109/9000
# Document 4110/9000
# Document 4111/9000
# Document 4112/9000
# Document 4113/9000
# Document 4114/9000
# Document 4115/9000
# Document 4116/9000
# Document 4117/9000
# Document 4118/9000
# Document 4119/9000
# Document 4120/9000
# Document 4121/9000
# Document 4122/9000
# Document 4123/9000
# Document 4124/9000
# Document 4125/9000
# Document 4126/9000
# Document 4127/9000
# Document 4128/9000
# Document 4129/9000
# Document 4130/9000
# Document 4131/9000
# Document 4132/9000
# Document 4133/9000
# Document 4134/9000
# Document 4134 has no title. Proceeding..
# Document 4136/9000
# Document 4137/9000
# Document 4138/9000
# Document 4139/9000
# Document 4140/9000
# Document 4141/9000
# Document 4142/9000
# Document 4143/9000
# Document 4144/9000
# Document 4145/9000
# Document 4146/9000
# Document 4147/9000
# Document 4148/9000
# Document 4149/9000
# Document 4150/9000
# Document 4151/9000
# Document 4152/9000
# Document 4153/9000
# Document 4154/9000
# Document 4155/9000
# Document 4156/9000
# Document 4157/9000
# Document 4158/9000
# Document 4159/9000
# Document 4160/9000
# Document 4161/9000
# Document 4162/9000
# Document 4163/9000
# Document 4164/9000
# Document 4165/9000
# Document 4166/9000
# Document 4167/9000
# Document 4168/9000
# Document 4169/9000
# Document 4170/9000
# Document 4171/9000
# Document 4172/9000
# Document 4173/9000
# Document 4174/9000
# Document 4175/9000
# Document 4176/9000
# Document 4177/9000
# Document 4178/9000
# Document 4179/9000
# Document 4180/9000
# Document 4181/9000
# Document 4182/9000
# Document 4183/9000
# Document 4184/9000
# Document 4185/9000
# Document 4186/9000
# Document 4187/9000
# Document 4188/9000
# Document 4189/9000
# Document 4190/9000
# Document 4191/9000
# Document 4192/9000
# Document 4193/9000
# Document 4194/9000
# Document 4195/9000
# Document 4196/9000
# Document 4197/9000
# Document 4198/9000
# Document 4199/9000
# Document 4200/9000
# Document 4201/9000
# Document 4202/9000
# Document 4203/9000
# Document 4204/9000
# Document 4205/9000
# Document 4206/9000
# Document 4207/9000
# Document 4208/9000
# Document 4209/9000
# Document 4210/9000
# Document 4211/9000
# Document 4212/9000
# Document 4213/9000
# Document 4214/9000
# Document 4215/9000
# Document 4216/9000
# Document 4217/9000
# Document 4218/9000
# Document 4219/9000
# Document 4220/9000
# Document 4221/9000
# Document 4222/9000
# Document 4223/9000
# Document 4224/9000
# Document 4225/9000
# Document 4226/9000
# Document 4227/9000
# Document 4228/9000
# Document 4229/9000
# Document 4230/9000
# Document 4231/9000
# Document 4232/9000
# Document 4233/9000
# Document 4234/9000
# Document 4235/9000
# Document 4236/9000
# Document 4237/9000
# Document 4238/9000
# Document 4238 has no title. Proceeding..
# Document 4240/9000
# Document 4241/9000
# Document 4242/9000
# Document 4243/9000
# Document 4244/9000
# Document 4245/9000
# Document 4246/9000
# Document 4247/9000
# Document 4248/9000
# Document 4248 has no title. Proceeding..
# Document 4250/9000
# Document 4251/9000
# Document 4252/9000
# Document 4253/9000
# Document 4254/9000
# Document 4254 has no title. Proceeding..
# Document 4256/9000
# Document 4257/9000
# Document 4258/9000
# Document 4259/9000
# Document 4260/9000
# Document 4261/9000
# Document 4262/9000
# Document 4263/9000
# Document 4264/9000
# Document 4265/9000
# Document 4266/9000
# Document 4267/9000
# Document 4268/9000
# Document 4269/9000
# Document 4270/9000
# Document 4271/9000
# Document 4272/9000
# Document 4273/9000
# Document 4274/9000
# Document 4275/9000
# Document 4276/9000
# Document 4277/9000
# Document 4278/9000
# Document 4279/9000
# Document 4280/9000
# Document 4281/9000
# Document 4282/9000
# Document 4283/9000
# Document 4284/9000
# Document 4285/9000
# Document 4286/9000
# Document 4287/9000
# Document 4288/9000
# Document 4289/9000
# Document 4290/9000
# Document 4290 has no title. Proceeding..
# Document 4292/9000
# Document 4293/9000
# Document 4294/9000
# Document 4295/9000
# Document 4296/9000
# Document 4297/9000
# Document 4298/9000
# Document 4299/9000
# Document 4300/9000
# Document 4300 has no title. Proceeding..
# Document 4302/9000
# Document 4303/9000
# Document 4304/9000
# Document 4305/9000
# Document 4306/9000
# Document 4307/9000
# Document 4308/9000
# Document 4309/9000
# Document 4310/9000
# Document 4311/9000
# Document 4312/9000
# Document 4313/9000
# Document 4314/9000
# Document 4315/9000
# Document 4316/9000
# Document 4317/9000
# Document 4318/9000
# Document 4319/9000
# Document 4320/9000
# Document 4321/9000
# Document 4322/9000
# Document 4323/9000
# Document 4324/9000
# Document 4325/9000
# Document 4326/9000
# Document 4327/9000
# Document 4328/9000
# Document 4329/9000
# Document 4330/9000
# Document 4331/9000
# Document 4332/9000
# Document 4333/9000
# Document 4334/9000
# Document 4335/9000
# Document 4336/9000
# Document 4337/9000
# Document 4338/9000
# Document 4339/9000
# Document 4340/9000
# Document 4341/9000
# Document 4342/9000
# Document 4343/9000
# Document 4344/9000
# Document 4345/9000
# Document 4346/9000
# Document 4347/9000
# Document 4348/9000
# Document 4349/9000
# Document 4350/9000
# Document 4351/9000
# Document 4352/9000
# Document 4353/9000
# Document 4354/9000
# Document 4355/9000
# Document 4356/9000
# Document 4357/9000
# Document 4358/9000
# Document 4359/9000
# Document 4360/9000
# Document 4361/9000
# Document 4362/9000
# Document 4363/9000
# Document 4364/9000
# Document 4365/9000
# Document 4366/9000
# Document 4367/9000
# Document 4368/9000
# Document 4369/9000
# Document 4370/9000
# Document 4371/9000
# Document 4372/9000
# Document 4373/9000
# Document 4374/9000
# Document 4375/9000
# Document 4376/9000
# Document 4377/9000
# Document 4378/9000
# Document 4379/9000
# Document 4380/9000
# Document 4381/9000
# Document 4382/9000
# Document 4383/9000
# Document 4384/9000
# Document 4385/9000
# Document 4385 has no title. Proceeding..
# Document 4387/9000
# Document 4388/9000
# Document 4389/9000
# Document 4390/9000
# Document 4391/9000
# Document 4392/9000
# Document 4393/9000
# Document 4394/9000
# Document 4394 has no title. Proceeding..
# Document 4396/9000
# Document 4397/9000
# Document 4398/9000
# Document 4398 has no title. Proceeding..
# Document 4400/9000
# Document 4401/9000
# Document 4402/9000
# Document 4403/9000
# Document 4404/9000
# Document 4405/9000
# Document 4406/9000
# Document 4407/9000
# Document 4408/9000
# Document 4409/9000
# Document 4410/9000
# Document 4411/9000
# Document 4412/9000
# Document 4413/9000
# Document 4414/9000
# Document 4415/9000
# Document 4416/9000
# Document 4417/9000
# Document 4418/9000
# Document 4419/9000
# Document 4420/9000
# Document 4421/9000
# Document 4422/9000
# Document 4423/9000
# Document 4424/9000
# Document 4425/9000
# Document 4426/9000
# Document 4427/9000
# Document 4428/9000
# Document 4429/9000
# Document 4429 has no title. Proceeding..
# Document 4431/9000
# Document 4432/9000
# Document 4433/9000
# Document 4434/9000
# Document 4435/9000
# Document 4436/9000
# Document 4437/9000
# Document 4438/9000
# Document 4439/9000
# Document 4440/9000
# Document 4441/9000
# Document 4442/9000
# Document 4443/9000
# Document 4444/9000
# Document 4445/9000
# Document 4446/9000
# Document 4447/9000
# Document 4448/9000
# Document 4449/9000
# Document 4450/9000
# Document 4451/9000
# Document 4452/9000
# Document 4453/9000
# Document 4454/9000
# Document 4455/9000
# Document 4456/9000
# Document 4457/9000
# Document 4458/9000
# Document 4459/9000
# Document 4460/9000
# Document 4461/9000
# Document 4462/9000
# Document 4463/9000
# Document 4464/9000
# Document 4465/9000
# Document 4466/9000
# Document 4467/9000
# Document 4468/9000
# Document 4469/9000
# Document 4470/9000
# Document 4471/9000
# Document 4472/9000
# Document 4473/9000
# Document 4474/9000
# Document 4475/9000
# Document 4476/9000
# Document 4477/9000
# Document 4477 has no title. Proceeding..
# Document 4479/9000
# Document 4480/9000
# Document 4481/9000
# Document 4482/9000
# Document 4483/9000
# Document 4484/9000
# Document 4485/9000
# Document 4486/9000
# Document 4487/9000
# Document 4488/9000
# Document 4489/9000
# Document 4490/9000
# Document 4491/9000
# Document 4492/9000
# Document 4493/9000
# Document 4494/9000
# Document 4495/9000
# Document 4496/9000
# Document 4497/9000
# Document 4498/9000
# Document 4499/9000
# Document 4500/9000
# Document 4501/9000
# Document 4501 has no title. Proceeding..
# Document 4503/9000
# Document 4504/9000
# Document 4505/9000
# Document 4506/9000
# Document 4507/9000
# Document 4508/9000
# Document 4509/9000
# Document 4509 has no title. Proceeding..
# Document 4511/9000
# Document 4512/9000
# Document 4513/9000
# Document 4514/9000
# Document 4515/9000
# Document 4516/9000
# Document 4517/9000
# Document 4518/9000
# Document 4518 has no title. Proceeding..
# Document 4520/9000
# Document 4521/9000
# Document 4522/9000
# Document 4523/9000
# Document 4524/9000
# Document 4525/9000
# Document 4526/9000
# Document 4527/9000
# Document 4528/9000
# Document 4529/9000
# Document 4530/9000
# Document 4531/9000
# Document 4532/9000
# Document 4533/9000
# Document 4534/9000
# Document 4535/9000
# Document 4536/9000
# Document 4537/9000
# Document 4538/9000
# Document 4539/9000
# Document 4540/9000
# Document 4541/9000
# Document 4542/9000
# Document 4543/9000
# Document 4544/9000
# Document 4545/9000
# Document 4546/9000
# Document 4547/9000
# Document 4548/9000
# Document 4549/9000
# Document 4550/9000
# Document 4551/9000
# Document 4552/9000
# No data on document 4552. Proceeding..
# Document 4554/9000
# Document 4555/9000
# Document 4556/9000
# Document 4557/9000
# Document 4558/9000
# Document 4559/9000
# Document 4560/9000
# Document 4561/9000
# Document 4562/9000
# Document 4563/9000
# Document 4564/9000
# Document 4565/9000
# Document 4566/9000
# Document 4567/9000
# Document 4568/9000
# Document 4569/9000
# Document 4569 has no title. Proceeding..
# Document 4571/9000
# Document 4572/9000
# Document 4573/9000
# Document 4574/9000
# Document 4575/9000
# Document 4576/9000
# Document 4577/9000
# Document 4578/9000
# Document 4579/9000
# Document 4580/9000
# Document 4581/9000
# Document 4582/9000
# Document 4583/9000
# Document 4584/9000
# Document 4585/9000
# Document 4586/9000
# Document 4587/9000
# Document 4588/9000
# Document 4589/9000
# Document 4590/9000
# Document 4591/9000
# Document 4592/9000
# Document 4593/9000
# Document 4594/9000
# Document 4595/9000
# Document 4595 has no title. Proceeding..
# Document 4597/9000
# Document 4598/9000
# Document 4599/9000
# Document 4600/9000
# Document 4601/9000
# Document 4602/9000
# Document 4603/9000
# Document 4604/9000
# Document 4605/9000
# Document 4606/9000
# Document 4607/9000
# Document 4608/9000
# Document 4609/9000
# Document 4610/9000
# Document 4611/9000
# Document 4612/9000
# Document 4613/9000
# Document 4614/9000
# Document 4615/9000
# Document 4616/9000
# Document 4617/9000
# Document 4618/9000
# Document 4619/9000
# Document 4620/9000
# Document 4621/9000
# Document 4622/9000
# Document 4623/9000
# Document 4624/9000
# Document 4625/9000
# Document 4626/9000
# Document 4627/9000
# Document 4628/9000
# Document 4629/9000
# Document 4630/9000
# Document 4631/9000
# Document 4631 has no title. Proceeding..
# Document 4632 has no title. Proceeding..
# Document 4634/9000
# Document 4635/9000
# Document 4636/9000
# Document 4637/9000
# Document 4638/9000
# Document 4639/9000
# Document 4640/9000
# Document 4641/9000
# Document 4642/9000
# Document 4643/9000
# Document 4644/9000
# Document 4645/9000
# Document 4645 has no title. Proceeding..
# No data on document 4646. Proceeding..
# Document 4648/9000
# Document 4649/9000
# Document 4650/9000
# Document 4651/9000
# Document 4652/9000
# Document 4653/9000
# Document 4654/9000
# Document 4655/9000
# Document 4656/9000
# Document 4657/9000
# Document 4658/9000
# Document 4659/9000
# Document 4660/9000
# Document 4661/9000
# Document 4662/9000
# Document 4663/9000
# Document 4664/9000
# Document 4665/9000
# Document 4666/9000
# Document 4667/9000
# Document 4668/9000
# Document 4669/9000
# Document 4670/9000
# Document 4671/9000
# Document 4672/9000
# Document 4673/9000
# Document 4674/9000
# Document 4675/9000
# Document 4675 has no title. Proceeding..
# Document 4677/9000
# Document 4678/9000
# Document 4679/9000
# Document 4680/9000
# Document 4680 has no title. Proceeding..
# Document 4682/9000
# Document 4683/9000
# Document 4684/9000
# Document 4685/9000
# Document 4686/9000
# Document 4687/9000
# Document 4688/9000
# Document 4689/9000
# Document 4690/9000
# Document 4690 has no title. Proceeding..
# Document 4692/9000
# Document 4693/9000
# Document 4694/9000
# Document 4695/9000
# Document 4696/9000
# Document 4697/9000
# Document 4698/9000
# Document 4699/9000
# Document 4700/9000
# Document 4701/9000
# Document 4702/9000
# Document 4703/9000
# Document 4704/9000
# Document 4705/9000
# Document 4706/9000
# Document 4707/9000
# Document 4707 has no title. Proceeding..
# Document 4709/9000
# Document 4710/9000
# Document 4711/9000
# Document 4712/9000
# Document 4713/9000
# Document 4714/9000
# Document 4715/9000
# Document 4716/9000
# Document 4717/9000
# Document 4718/9000
# Document 4719/9000
# Document 4720/9000
# Document 4721/9000
# Document 4722/9000
# Document 4723/9000
# Document 4724/9000
# Document 4725/9000
# Document 4726/9000
# Document 4727/9000
# Document 4728/9000
# Document 4729/9000
# Document 4730/9000
# Document 4731/9000
# Document 4732/9000
# Document 4733/9000
# Document 4734/9000
# Document 4735/9000
# Document 4736/9000
# Document 4737/9000
# Document 4738/9000
# Document 4739/9000
# Document 4740/9000
# Document 4741/9000
# Document 4742/9000
# Document 4743/9000
# Document 4744/9000
# Document 4745/9000
# Document 4746/9000
# Document 4747/9000
# Document 4748/9000
# Document 4749/9000
# Document 4750/9000
# Document 4751/9000
# Document 4752/9000
# Document 4753/9000
# Document 4754/9000
# Document 4755/9000
# Document 4756/9000
# Document 4757/9000
# Document 4758/9000
# Document 4759/9000
# Document 4760/9000
# Document 4761/9000
# Document 4762/9000
# Document 4762 has no title. Proceeding..
# Document 4764/9000
# Document 4765/9000
# Document 4766/9000
# Document 4767/9000
# Document 4768/9000
# Document 4769/9000
# Document 4769 has no title. Proceeding..
# Document 4771/9000
# Document 4772/9000
# Document 4773/9000
# Document 4774/9000
# Document 4775/9000
# Document 4776/9000
# Document 4777/9000
# Document 4778/9000
# Document 4779/9000
# Document 4780/9000
# Document 4781/9000
# Document 4782/9000
# Document 4783/9000
# Document 4784/9000
# Document 4785/9000
# Document 4786/9000
# Document 4787/9000
# Document 4788/9000
# Document 4789/9000
# Document 4790/9000
# Document 4790 has no title. Proceeding..
# Document 4792/9000
# Document 4793/9000
# Document 4794/9000
# Document 4795/9000
# Document 4796/9000
# Document 4797/9000
# Document 4798/9000
# Document 4799/9000
# Document 4800/9000
# Document 4801/9000
# Document 4802/9000
# Document 4803/9000
# Document 4804/9000
# Document 4804 has no title. Proceeding..
# Document 4806/9000
# Document 4807/9000
# Document 4808/9000
# Document 4808 has no title. Proceeding..
# Document 4810/9000
# Document 4811/9000
# Document 4812/9000
# Document 4813/9000
# Document 4814/9000
# Document 4815/9000
# Document 4815 has no title. Proceeding..
# Document 4817/9000
# Document 4818/9000
# Document 4819/9000
# Document 4820/9000
# Document 4821/9000
# Document 4822/9000
# Document 4823/9000
# Document 4824/9000
# Document 4825/9000
# Document 4826/9000
# Document 4827/9000
# Document 4828/9000
# Document 4829/9000
# Document 4830/9000
# Document 4831/9000
# Document 4832/9000
# Document 4833/9000
# Document 4834/9000
# Document 4835/9000
# Document 4836/9000
# Document 4837/9000
# Document 4838/9000
# Document 4838 has no title. Proceeding..
# Document 4840/9000
# Document 4841/9000
# Document 4842/9000
# Document 4843/9000
# Document 4844/9000
# Document 4845/9000
# Document 4846/9000
# Document 4847/9000
# Document 4848/9000
# Document 4849/9000
# Document 4850/9000
# Document 4851/9000
# Document 4852/9000
# Document 4853/9000
# Document 4854/9000
# Document 4855/9000
# Document 4856/9000
# Document 4857/9000
# Document 4858/9000
# Document 4859/9000
# Document 4860/9000
# Document 4861/9000
# Document 4862/9000
# Document 4863/9000
# Document 4864/9000
# Document 4865/9000
# Document 4866/9000
# Document 4867/9000
# Document 4868/9000
# Document 4869/9000
# Document 4870/9000
# Document 4871/9000
# Document 4872/9000
# Document 4873/9000
# Document 4874/9000
# Document 4875/9000
# Document 4876/9000
# Document 4877/9000
# Document 4878/9000
# Document 4879/9000
# Document 4880/9000
# Document 4881/9000
# Document 4882/9000
# Document 4883/9000
# Document 4884/9000
# Document 4885/9000
# Document 4886/9000
# Document 4887/9000
# Document 4888/9000
# Document 4889/9000
# Document 4890/9000
# Document 4891/9000
# Document 4892/9000
# Document 4893/9000
# Document 4894/9000
# Document 4895/9000
# Document 4896/9000
# Document 4897/9000
# Document 4898/9000
# Document 4899/9000
# Document 4900/9000
# Document 4901/9000
# Document 4902/9000
# Document 4903/9000
# Document 4904/9000
# Document 4905/9000
# Document 4906/9000
# Document 4907/9000
# Document 4908/9000
# Document 4909/9000
# Document 4910/9000
# Document 4911/9000
# Document 4912/9000
# Document 4913/9000
# Document 4914/9000
# Document 4915/9000
# Document 4916/9000
# Document 4917/9000
# Document 4918/9000
# Document 4919/9000
# Document 4920/9000
# Document 4921/9000
# Document 4922/9000
# Document 4923/9000
# Document 4924/9000
# Document 4925/9000
# Document 4926/9000
# Document 4927/9000
# Document 4928/9000
# Document 4929/9000
# Document 4929 has no title. Proceeding..
# Document 4931/9000
# Document 4932/9000
# Document 4933/9000
# Document 4934/9000
# Document 4935/9000
# Document 4936/9000
# Document 4937/9000
# Document 4938/9000
# Document 4939/9000
# Document 4940/9000
# Document 4941/9000
# Document 4942/9000
# Document 4943/9000
# Document 4944/9000
# Document 4945/9000
# Document 4946/9000
# Document 4947/9000
# Document 4948/9000
# Document 4949/9000
# Document 4950/9000
# Document 4951/9000
# Document 4952/9000
# Document 4953/9000
# Document 4954/9000
# Document 4955/9000
# Document 4956/9000
# Document 4957/9000
# Document 4958/9000
# Document 4959/9000
# Document 4959 has no title. Proceeding..
# Document 4961/9000
# Document 4962/9000
# Document 4963/9000
# Document 4964/9000
# Document 4965/9000
# Document 4966/9000
# Document 4967/9000
# Document 4968/9000
# Document 4969/9000
# Document 4970/9000
# Document 4971/9000
# Document 4972/9000
# Document 4973/9000
# Document 4974/9000
# Document 4975/9000
# Document 4976/9000
# Document 4977/9000
# Document 4978/9000
# Document 4979/9000
# Document 4980/9000
# Document 4981/9000
# Document 4982/9000
# Document 4983/9000
# Document 4984/9000
# Document 4985/9000
# Document 4986/9000
# Document 4986 has no title. Proceeding..
# Document 4988/9000
# Document 4989/9000
# Document 4990/9000
# Document 4991/9000
# Document 4992/9000
# Document 4993/9000
# Document 4994/9000
# Document 4995/9000
# Document 4996/9000
# Document 4996 has no title. Proceeding..
# Document 4998/9000
# Document 4999/9000
# Document 5000/9000
# Document 5001/9000
# Document 5002/9000
# Document 5003/9000
# Document 5004/9000
# Document 5005/9000
# Document 5006/9000
# Document 5007/9000
# Document 5008/9000
# Document 5009/9000
# Document 5010/9000
# Document 5011/9000
# Document 5012/9000
# Document 5013/9000
# Document 5014/9000
# Document 5015/9000
# Document 5016/9000
# Document 5017/9000
# Document 5017 has no title. Proceeding..
# Document 5019/9000
# Document 5020/9000
# Document 5021/9000
# Document 5022/9000
# Document 5023/9000
# Document 5024/9000
# Document 5025/9000
# Document 5025 has no title. Proceeding..
# Document 5027/9000
# Document 5028/9000
# Document 5029/9000
# Document 5030/9000
# Document 5031/9000
# Document 5032/9000
# Document 5033/9000
# Document 5034/9000
# Document 5035/9000
# Document 5035 has no title. Proceeding..
# Document 5037/9000
# Document 5038/9000
# Document 5039/9000
# Document 5040/9000
# Document 5041/9000
# Document 5042/9000
# Document 5043/9000
# Document 5044/9000
# Document 5045/9000
# Document 5046/9000
# Document 5047/9000
# Document 5047 has no title. Proceeding..
# Document 5049/9000
# Document 5050/9000
# Document 5051/9000
# Document 5052/9000
# Document 5053/9000
# Document 5054/9000
# Document 5055/9000
# Document 5056/9000
# Document 5057/9000
# Document 5058/9000
# Document 5059/9000
# Document 5060/9000
# Document 5061/9000
# Document 5062/9000
# Document 5063/9000
# Document 5064/9000
# Document 5065/9000
# Document 5066/9000
# Document 5066 has no title. Proceeding..
# Document 5068/9000
# Document 5069/9000
# Document 5070/9000
# Document 5071/9000
# Document 5071 has no title. Proceeding..
# Document 5073/9000
# Document 5074/9000
# Document 5075/9000
# Document 5076/9000
# Document 5077/9000
# Document 5078/9000
# Document 5079/9000
# Document 5080/9000
# Document 5081/9000
# Document 5082/9000
# Document 5083/9000
# Document 5084/9000
# Document 5085/9000
# Document 5086/9000
# Document 5087/9000
# Document 5088/9000
# Document 5089/9000
# Document 5089 has no title. Proceeding..
# Document 5091/9000
# Document 5092/9000
# Document 5093/9000
# Document 5094/9000
# Document 5095/9000
# Document 5096/9000
# Document 5097/9000
# Document 5098/9000
# Document 5099/9000
# Document 5100/9000
# Document 5101/9000
# Document 5102/9000
# Document 5103/9000
# Document 5104/9000
# Document 5105/9000
# Document 5106/9000
# Document 5107/9000
# Document 5108/9000
# Document 5109/9000
# Document 5110/9000
# Document 5111/9000
# Document 5112/9000
# Document 5113/9000
# Document 5114/9000
# Document 5115/9000
# Document 5116/9000
# Document 5117/9000
# Document 5118/9000
# Document 5119/9000
# Document 5120/9000
# Document 5121/9000
# Document 5122/9000
# Document 5123/9000
# Document 5124/9000
# Document 5125/9000
# Document 5126/9000
# Document 5127/9000
# Document 5128/9000
# Document 5129/9000
# Document 5130/9000
# Document 5131/9000
# Document 5132/9000
# Document 5133/9000
# Document 5134/9000
# Document 5135/9000
# Document 5136/9000
# Document 5137/9000
# Document 5138/9000
# Document 5139/9000
# Document 5140/9000
# Document 5141/9000
# Document 5142/9000
# Document 5143/9000
# Document 5144/9000
# Document 5145/9000
# Document 5146/9000
# Document 5147/9000
# Document 5148/9000
# Document 5149/9000
# Document 5150/9000
# Document 5151/9000
# Document 5152/9000
# Document 5153/9000
# Document 5153 has no title. Proceeding..
# Document 5155/9000
# Document 5156/9000
# Document 5157/9000
# Document 5158/9000
# Document 5159/9000
# Document 5160/9000
# Document 5161/9000
# Document 5162/9000
# Document 5163/9000
# Document 5164/9000
# Document 5165/9000
# Document 5166/9000
# Document 5167/9000
# Document 5168/9000
# Document 5169/9000
# Document 5170/9000
# Document 5171/9000
# Document 5172/9000
# Document 5173/9000
# Document 5174/9000
# Document 5175/9000
# Document 5176/9000
# Document 5177/9000
# Document 5178/9000
# Document 5179/9000
# Document 5180/9000
# Document 5180 has no title. Proceeding..
# Document 5182/9000
# Document 5183/9000
# Document 5184/9000
# Document 5185/9000
# Document 5186/9000
# Document 5187/9000
# Document 5188/9000
# Document 5189/9000
# Document 5190/9000
# Document 5191/9000
# Document 5192/9000
# Document 5193/9000
# Document 5194/9000
# Document 5195/9000
# Document 5196/9000
# Document 5197/9000
# Document 5198/9000
# Document 5199/9000
# Document 5200/9000
# Document 5201/9000
# Document 5202/9000
# Document 5203/9000
# Document 5204/9000
# Document 5205/9000
# Document 5206/9000
# Document 5207/9000
# Document 5208/9000
# Document 5209/9000
# Document 5210/9000
# Document 5211/9000
# Document 5212/9000
# Document 5213/9000
# Document 5214/9000
# Document 5215/9000
# Document 5216/9000
# Document 5217/9000
# Document 5218/9000
# Document 5219/9000
# Document 5219 has no title. Proceeding..
# Document 5221/9000
# Document 5222/9000
# Document 5223/9000
# Document 5224/9000
# Document 5225/9000
# Document 5226/9000
# Document 5227/9000
# Document 5228/9000
# Document 5229/9000
# Document 5230/9000
# Document 5231/9000
# Document 5232/9000
# Document 5233/9000
# Document 5234/9000
# Document 5235/9000
# Document 5236/9000
# Document 5237/9000
# Document 5238/9000
# Document 5239/9000
# Document 5240/9000
# Document 5241/9000
# Document 5242/9000
# Document 5243/9000
# Document 5243 has no title. Proceeding..
# Document 5245/9000
# Document 5246/9000
# Document 5247/9000
# Document 5248/9000
# Document 5249/9000
# Document 5250/9000
# Document 5251/9000
# Document 5252/9000
# Document 5253/9000
# Document 5253 has no title. Proceeding..
# Document 5255/9000
# Document 5256/9000
# Document 5257/9000
# Document 5258/9000
# Document 5259/9000
# Document 5260/9000
# Document 5261/9000
# Document 5262/9000
# Document 5263/9000
# Document 5264/9000
# Document 5265/9000
# Document 5266/9000
# Document 5267/9000
# Document 5268/9000
# Document 5269/9000
# Document 5270/9000
# Document 5271/9000
# Document 5272/9000
# Document 5273/9000
# Document 5274/9000
# Document 5275/9000
# Document 5276/9000
# Document 5277/9000
# Document 5278/9000
# Document 5279/9000
# Document 5280/9000
# Document 5281/9000
# Document 5281 has no title. Proceeding..
# Document 5283/9000
# Document 5284/9000
# Document 5285/9000
# Document 5286/9000
# Document 5287/9000
# Document 5288/9000
# Document 5288 has no title. Proceeding..
# Document 5290/9000
# Document 5291/9000
# Document 5292/9000
# Document 5293/9000
# Document 5294/9000
# Document 5295/9000
# Document 5296/9000
# Document 5297/9000
# Document 5298/9000
# Document 5299/9000
# Document 5300/9000
# Document 5301/9000
# Document 5302/9000
# Document 5303/9000
# Document 5304/9000
# Document 5305/9000
# Document 5306/9000
# Document 5307/9000
# Document 5308/9000
# Document 5309/9000
# Document 5310/9000
# Document 5311/9000
# Document 5312/9000
# Document 5313/9000
# Document 5314/9000
# Document 5315/9000
# Document 5316/9000
# Document 5317/9000
# Document 5318/9000
# Document 5319/9000
# Document 5320/9000
# Document 5321/9000
# Document 5322/9000
# Document 5323/9000
# Document 5324/9000
# Document 5325/9000
# Document 5326/9000
# Document 5326 has no title. Proceeding..
# Document 5328/9000
# Document 5329/9000
# Document 5330/9000
# Document 5331/9000
# Document 5332/9000
# Document 5333/9000
# Document 5334/9000
# Document 5335/9000
# Document 5336/9000
# Document 5336 has no title. Proceeding..
# Document 5338/9000
# Document 5339/9000
# Document 5340/9000
# Document 5341/9000
# Document 5342/9000
# Document 5343/9000
# Document 5343 has no title. Proceeding..
# Document 5345/9000
# Document 5346/9000
# Document 5347/9000
# Document 5348/9000
# Document 5349/9000
# Document 5350/9000
# Document 5351/9000
# Document 5352/9000
# Document 5353/9000
# Document 5354/9000
# Document 5355/9000
# Document 5356/9000
# Document 5357/9000
# Document 5358/9000
# Document 5359/9000
# Document 5360/9000
# Document 5361/9000
# Document 5361 has no title. Proceeding..
# Document 5363/9000
# Document 5364/9000
# Document 5365/9000
# Document 5366/9000
# Document 5367/9000
# Document 5368/9000
# Document 5369/9000
# Document 5370/9000
# Document 5371/9000
# Document 5372/9000
# Document 5373/9000
# Document 5374/9000
# Document 5375/9000
# Document 5376/9000
# Document 5377/9000
# Document 5378/9000
# Document 5379/9000
# Document 5380/9000
# Document 5381/9000
# Document 5382/9000
# Document 5383/9000
# Document 5384/9000
# Document 5385/9000
# Document 5386/9000
# Document 5387/9000
# Document 5388/9000
# Document 5389/9000
# Document 5390/9000
# Document 5391/9000
# Document 5391 has no title. Proceeding..
# Document 5393/9000
# Document 5394/9000
# Document 5394 has no title. Proceeding..
# Document 5396/9000
# Document 5397/9000
# Document 5398/9000
# Document 5398 has no title. Proceeding..
# Document 5400/9000
# Document 5401/9000
# Document 5402/9000
# Document 5403/9000
# Document 5403 has no title. Proceeding..
# Document 5405/9000
# Document 5406/9000
# Document 5407/9000
# Document 5408/9000
# Document 5409/9000
# Document 5410/9000
# Document 5411/9000
# Document 5412/9000
# Document 5413/9000
# Document 5414/9000
# Document 5415/9000
# Document 5416/9000
# Document 5417/9000
# Document 5418/9000
# Document 5419/9000
# Document 5420/9000
# Document 5421/9000
# Document 5422/9000
# Document 5423/9000
# Document 5424/9000
# Document 5425/9000
# Document 5426/9000
# Document 5427/9000
# Document 5428/9000
# Document 5429/9000
# Document 5430/9000
# Document 5431/9000
# Document 5432/9000
# Document 5433/9000
# Document 5434/9000
# Document 5435/9000
# Document 5436/9000
# Document 5437/9000
# Document 5438/9000
# Document 5439/9000
# Document 5440/9000
# Document 5440 has no title. Proceeding..
# Document 5442/9000
# Document 5443/9000
# Document 5444/9000
# Document 5445/9000
# Document 5445 has no title. Proceeding..
# Document 5447/9000
# Document 5448/9000
# Document 5449/9000
# Document 5450/9000
# Document 5451/9000
# Document 5452/9000
# Document 5453/9000
# Document 5454/9000
# Document 5455/9000
# Document 5456/9000
# Document 5457/9000
# Document 5458/9000
# Document 5459/9000
# Document 5460/9000
# Document 5461/9000
# Document 5462/9000
# Document 5463/9000
# Document 5464/9000
# Document 5465/9000
# Document 5466/9000
# Document 5467/9000
# Document 5468/9000
# Document 5469/9000
# Document 5470/9000
# Document 5471/9000
# Document 5472/9000
# Document 5473/9000
# Document 5474/9000
# Document 5475/9000
# Document 5476/9000
# Document 5477/9000
# Document 5478/9000
# Document 5479/9000
# Document 5480/9000
# Document 5481/9000
# Document 5482/9000
# Document 5483/9000
# Document 5484/9000
# Document 5485/9000
# Document 5486/9000
# Document 5487/9000
# Document 5488/9000
# Document 5489/9000
# Document 5490/9000
# Document 5491/9000
# Document 5492/9000
# Document 5493/9000
# Document 5494/9000
# Document 5495/9000
# Document 5496/9000
# Document 5497/9000
# Document 5498/9000
# Document 5499/9000
# Document 5500/9000
# Document 5501/9000
# Document 5502/9000
# Document 5503/9000
# Document 5504/9000
# Document 5505/9000
# Document 5506/9000
# Document 5507/9000
# Document 5508/9000
# Document 5509/9000
# Document 5510/9000
# Document 5511/9000
# Document 5512/9000
# Document 5513/9000
# Document 5514/9000
# Document 5515/9000
# Document 5516/9000
# Document 5517/9000
# Document 5518/9000
# Document 5519/9000
# Document 5520/9000
# Document 5521/9000
# Document 5522/9000
# Document 5523/9000
# Document 5524/9000
# Document 5525/9000
# Document 5526/9000
# Document 5527/9000
# Document 5528/9000
# Document 5529/9000
# Document 5530/9000
# Document 5531/9000
# Document 5532/9000
# Document 5533/9000
# Document 5534/9000
# Document 5535/9000
# Document 5536/9000
# Document 5537/9000
# Document 5538/9000
# Document 5539/9000
# Document 5540/9000
# Document 5541/9000
# Document 5542/9000
# Document 5543/9000
# Document 5544/9000
# Document 5545/9000
# Document 5546/9000
# Document 5547/9000
# Document 5548/9000
# Document 5549/9000
# Document 5550/9000
# Document 5551/9000
# Document 5552/9000
# Document 5553/9000
# Document 5554/9000
# Document 5555/9000
# Document 5556/9000
# Document 5557/9000
# Document 5558/9000
# Document 5559/9000
# Document 5560/9000
# Document 5561/9000
# Document 5562/9000
# Document 5563/9000
# Document 5564/9000
# Document 5565/9000
# Document 5566/9000
# Document 5567/9000
# Document 5568/9000
# Document 5569/9000
# Document 5570/9000
# Document 5571/9000
# Document 5572/9000
# Document 5573/9000
# Document 5574/9000
# Document 5574 has no title. Proceeding..
# Document 5576/9000
# Document 5577/9000
# Document 5578/9000
# Document 5579/9000
# Document 5580/9000
# Document 5581/9000
# Document 5582/9000
# Document 5583/9000
# Document 5584/9000
# Document 5585/9000
# Document 5586/9000
# Document 5586 has no title. Proceeding..
# Document 5587 has no title. Proceeding..
# Document 5589/9000
# Document 5590/9000
# Document 5591/9000
# Document 5592/9000
# Document 5593/9000
# Document 5594/9000
# Document 5595/9000
# Document 5596/9000
# Document 5597/9000
# Document 5598/9000
# Document 5599/9000
# Document 5600/9000
# Document 5601/9000
# Document 5602/9000
# Document 5603/9000
# Document 5604/9000
# Document 5605/9000
# Document 5606/9000
# Document 5607/9000
# Document 5608/9000
# Document 5609/9000
# Document 5610/9000
# Document 5611/9000
# Document 5612/9000
# Document 5613/9000
# Document 5614/9000
# Document 5615/9000
# Document 5616/9000
# Document 5617/9000
# Document 5618/9000
# Document 5619/9000
# Document 5620/9000
# Document 5621/9000
# Document 5622/9000
# Document 5623/9000
# Document 5624/9000
# Document 5625/9000
# Document 5626/9000
# Document 5627/9000
# Document 5628/9000
# Document 5629/9000
# Document 5630/9000
# Document 5631/9000
# Document 5632/9000
# Document 5633/9000
# Document 5634/9000
# Document 5635/9000
# Document 5636/9000
# Document 5637/9000
# Document 5638/9000
# Document 5639/9000
# Document 5640/9000
# Document 5641/9000
# Document 5641 has no title. Proceeding..
# Document 5643/9000
# Document 5644/9000
# Document 5645/9000
# Document 5646/9000
# Document 5647/9000
# Document 5647 has no title. Proceeding..
# Document 5649/9000
# Document 5650/9000
# Document 5651/9000
# Document 5652/9000
# Document 5653/9000
# Document 5654/9000
# Document 5655/9000
# Document 5655 has no title. Proceeding..
# Document 5657/9000
# Document 5658/9000
# Document 5659/9000
# Document 5660/9000
# Document 5661/9000
# Document 5662/9000
# Document 5663/9000
# Document 5664/9000
# Document 5665/9000
# Document 5666/9000
# Document 5667/9000
# Document 5668/9000
# Document 5669/9000
# Document 5670/9000
# Document 5671/9000
# Document 5672/9000
# Document 5673/9000
# Document 5674/9000
# Document 5675/9000
# Document 5676/9000
# Document 5677/9000
# Document 5678/9000
# Document 5679/9000
# Document 5680/9000
# Document 5681/9000
# Document 5682/9000
# Document 5683/9000
# Document 5684/9000
# Document 5685/9000
# Document 5686/9000
# Document 5687/9000
# Document 5688/9000
# Document 5688 has no title. Proceeding..
# Document 5690/9000
# Document 5691/9000
# Document 5692/9000
# Document 5693/9000
# Document 5694/9000
# Document 5695/9000
# Document 5696/9000
# Document 5697/9000
# Document 5698/9000
# Document 5699/9000
# Document 5700/9000
# Document 5701/9000
# Document 5702/9000
# Document 5703/9000
# Document 5704/9000
# Document 5704 has no title. Proceeding..
# Document 5706/9000
# Document 5707/9000
# Document 5708/9000
# Document 5709/9000
# Document 5710/9000
# Document 5711/9000
# Document 5712/9000
# Document 5713/9000
# Document 5714/9000
# Document 5715/9000
# Document 5716/9000
# Document 5717/9000
# Document 5718/9000
# Document 5719/9000
# Document 5720/9000
# Document 5721/9000
# Document 5722/9000
# Document 5723/9000
# Document 5724/9000
# Document 5725/9000
# Document 5726/9000
# Document 5727/9000
# Document 5728/9000
# Document 5729/9000
# Document 5730/9000
# Document 5731/9000
# Document 5731 has no title. Proceeding..
# Document 5733/9000
# Document 5733 has no title. Proceeding..
# Document 5735/9000
# Document 5735 has no title. Proceeding..
# Document 5737/9000
# Document 5738/9000
# Document 5739/9000
# Document 5740/9000
# Document 5741/9000
# Document 5742/9000
# Document 5743/9000
# Document 5744/9000
# Document 5745/9000
# Document 5746/9000
# Document 5747/9000
# Document 5748/9000
# Document 5749/9000
# Document 5750/9000
# Document 5751/9000
# Document 5752/9000
# Document 5753/9000
# Document 5754/9000
# Document 5755/9000
# Document 5756/9000
# Document 5757/9000
# Document 5758/9000
# Document 5759/9000
# Document 5760/9000
# Document 5761/9000
# Document 5762/9000
# Document 5763/9000
# Document 5764/9000
# Document 5765/9000
# Document 5766/9000
# Document 5767/9000
# Document 5768/9000
# Document 5769/9000
# Document 5770/9000
# Document 5770 has no title. Proceeding..
# Document 5772/9000
# Document 5773/9000
# Document 5774/9000
# Document 5775/9000
# Document 5776/9000
# Document 5777/9000
# Document 5778/9000
# Document 5779/9000
# Document 5780/9000
# Document 5781/9000
# Document 5782/9000
# Document 5783/9000
# Document 5784/9000
# Document 5785/9000
# Document 5786/9000
# Document 5786 has no title. Proceeding..
# Document 5788/9000
# Document 5789/9000
# Document 5790/9000
# Document 5791/9000
# Document 5792/9000
# Document 5793/9000
# Document 5794/9000
# Document 5795/9000
# Document 5796/9000
# Document 5797/9000
# Document 5798/9000
# Document 5799/9000
# Document 5800/9000
# Document 5801/9000
# Document 5802/9000
# Document 5803/9000
# Document 5804/9000
# Document 5805/9000
# Document 5806/9000
# Document 5807/9000
# Document 5808/9000
# Document 5809/9000
# Document 5810/9000
# Document 5811/9000
# Document 5812/9000
# Document 5813/9000
# Document 5814/9000
# Document 5815/9000
# Document 5816/9000
# Document 5817/9000
# Document 5818/9000
# Document 5819/9000
# Document 5820/9000
# Document 5821/9000
# Document 5822/9000
# Document 5823/9000
# Document 5824/9000
# Document 5825/9000
# Document 5825 has no title. Proceeding..
# Document 5827/9000
# Document 5828/9000
# Document 5828 has no title. Proceeding..
# Document 5830/9000
# Document 5831/9000
# Document 5832/9000
# Document 5833/9000
# Document 5834/9000
# Document 5835/9000
# Document 5836/9000
# No data on document 5836. Proceeding..
# Document 5838/9000
# Document 5839/9000
# Document 5840/9000
# Document 5841/9000
# Document 5842/9000
# Document 5843/9000
# Document 5844/9000
# Document 5845/9000
# Document 5846/9000
# Document 5847/9000
# Document 5848/9000
# Document 5849/9000
# Document 5850/9000
# Document 5851/9000
# Document 5852/9000
# Document 5853/9000
# Document 5854/9000
# Document 5855/9000
# Document 5856/9000
# Document 5857/9000
# Document 5858/9000
# Document 5859/9000
# Document 5860/9000
# Document 5861/9000
# Document 5862/9000
# Document 5863/9000
# Document 5864/9000
# Document 5865/9000
# Document 5866/9000
# Document 5867/9000
# Document 5868/9000
# Document 5869/9000
# Document 5870/9000
# Document 5871/9000
# Document 5872/9000
# Document 5873/9000
# Document 5874/9000
# Document 5875/9000
# Document 5876/9000
# Document 5877/9000
# Document 5878/9000
# Document 5879/9000
# Document 5880/9000
# Document 5881/9000
# Document 5882/9000
# Document 5883/9000
# Document 5884/9000
# Document 5885/9000
# Document 5886/9000
# Document 5887/9000
# Document 5888/9000
# Document 5889/9000
# Document 5890/9000
# Document 5890 has no title. Proceeding..
# Document 5892/9000
# Document 5893/9000
# Document 5894/9000
# Document 5895/9000
# Document 5896/9000
# Document 5897/9000
# Document 5898/9000
# Document 5899/9000
# Document 5900/9000
# Document 5901/9000
# Document 5902/9000
# Document 5903/9000
# Document 5903 has no title. Proceeding..
# Document 5905/9000
# Document 5906/9000
# Document 5907/9000
# Document 5908/9000
# Document 5909/9000
# Document 5910/9000
# Document 5911/9000
# Document 5912/9000
# Document 5913/9000
# Document 5914/9000
# Document 5915/9000
# Document 5916/9000
# Document 5917/9000
# Document 5918/9000
# Document 5919/9000
# Document 5919 has no title. Proceeding..
# Document 5921/9000
# Document 5922/9000
# Document 5923/9000
# Document 5924/9000
# Document 5925/9000
# Document 5926/9000
# Document 5927/9000
# Document 5928/9000
# Document 5929/9000
# Document 5930/9000
# Document 5931/9000
# Document 5932/9000
# Document 5933/9000
# Document 5934/9000
# Document 5935/9000
# Document 5936/9000
# Document 5937/9000
# Document 5938/9000
# Document 5939/9000
# Document 5940/9000
# Document 5941/9000
# Document 5942/9000
# Document 5943/9000
# Document 5944/9000
# Document 5945/9000
# Document 5946/9000
# Document 5947/9000
# Document 5948/9000
# Document 5949/9000
# Document 5950/9000
# Document 5951/9000
# Document 5952/9000
# Document 5953/9000
# Document 5954/9000
# Document 5955/9000
# Document 5956/9000
# Document 5957/9000
# Document 5958/9000
# Document 5959/9000
# Document 5960/9000
# Document 5961/9000
# Document 5962/9000
# Document 5963/9000
# Document 5964/9000
# Document 5965/9000
# Document 5966/9000
# Document 5967/9000
# Document 5968/9000
# Document 5969/9000
# Document 5970/9000
# Document 5970 has no title. Proceeding..
# Document 5972/9000
# Document 5973/9000
# Document 5974/9000
# Document 5975/9000
# Document 5976/9000
# Document 5977/9000
# Document 5978/9000
# Document 5979/9000
# Document 5980/9000
# Document 5981/9000
# Document 5982/9000
# Document 5983/9000
# Document 5984/9000
# Document 5985/9000
# Document 5986/9000
# Document 5987/9000
# Document 5988/9000
# Document 5989/9000
# Document 5990/9000
# Document 5991/9000
# Document 5992/9000
# Document 5993/9000
# Document 5994/9000
# Document 5995/9000
# Document 5996/9000
# Document 5997/9000
# Document 5998/9000
# Document 5999/9000
# Document 6000/9000
# Document 6001/9000
# Document 6002/9000
# Document 6003/9000
# Document 6003 has no title. Proceeding..
# Document 6005/9000
# Document 6006/9000
# Document 6007/9000
# Document 6008/9000
# Document 6009/9000
# Document 6010/9000
# Document 6011/9000
# Document 6012/9000
# Document 6013/9000
# Document 6014/9000
# Document 6015/9000
# Document 6016/9000
# Document 6016 has no title. Proceeding..
# Document 6018/9000
# Document 6019/9000
# Document 6020/9000
# Document 6021/9000
# Document 6022/9000
# Document 6023/9000
# Document 6024/9000
# Document 6025/9000
# Document 6026/9000
# Document 6027/9000
# Document 6028/9000
# Document 6029/9000
# Document 6030/9000
# Document 6031/9000
# Document 6032/9000
# Document 6032 has no title. Proceeding..
# Document 6034/9000
# Document 6035/9000
# Document 6036/9000
# Document 6037/9000
# Document 6038/9000
# Document 6039/9000
# Document 6040/9000
# Document 6041/9000
# Document 6042/9000
# Document 6043/9000
# Document 6044/9000
# Document 6045/9000
# Document 6046/9000
# Document 6047/9000
# Document 6048/9000
# Document 6049/9000
# Document 6050/9000
# Document 6051/9000
# Document 6052/9000
# Document 6053/9000
# Document 6054/9000
# Document 6055/9000
# Document 6056/9000
# Document 6057/9000
# Document 6058/9000
# Document 6059/9000
# Document 6060/9000
# Document 6061/9000
# Document 6062/9000
# Document 6063/9000
# Document 6064/9000
# Document 6065/9000
# Document 6066/9000
# Document 6067/9000
# Document 6068/9000
# Document 6069/9000
# Document 6070/9000
# Document 6071/9000
# Document 6072/9000
# Document 6073/9000
# Document 6074/9000
# Document 6075/9000
# Document 6076/9000
# Document 6077/9000
# Document 6078/9000
# Document 6079/9000
# Document 6080/9000
# Document 6081/9000
# Document 6082/9000
# Document 6083/9000
# Document 6084/9000
# Document 6085/9000
# Document 6086/9000
# Document 6087/9000
# Document 6088/9000
# Document 6089/9000
# No data on document 6089. Proceeding..
# Document 6091/9000
# Document 6092/9000
# Document 6093/9000
# Document 6094/9000
# Document 6095/9000
# Document 6096/9000
# Document 6097/9000
# Document 6098/9000
# Document 6099/9000
# Document 6100/9000
# Document 6101/9000
# Document 6102/9000
# Document 6103/9000
# Document 6104/9000
# Document 6105/9000
# Document 6106/9000
# Document 6107/9000
# Document 6108/9000
# Document 6109/9000
# Document 6110/9000
# Document 6110 has no title. Proceeding..
# Document 6112/9000
# Document 6113/9000
# Document 6114/9000
# Document 6115/9000
# Document 6116/9000
# Document 6117/9000
# Document 6118/9000
# Document 6119/9000
# Document 6120/9000
# Document 6121/9000
# Document 6122/9000
# Document 6123/9000
# Document 6124/9000
# Document 6125/9000
# Document 6126/9000
# Document 6127/9000
# Document 6128/9000
# Document 6129/9000
# Document 6130/9000
# Document 6131/9000
# Document 6132/9000
# Document 6133/9000
# Document 6134/9000
# Document 6135/9000
# Document 6136/9000
# Document 6137/9000
# Document 6138/9000
# Document 6139/9000
# Document 6140/9000
# Document 6141/9000
# Document 6142/9000
# Document 6143/9000
# Document 6144/9000
# Document 6145/9000
# Document 6146/9000
# Document 6147/9000
# Document 6148/9000
# Document 6149/9000
# Document 6150/9000
# Document 6151/9000
# Document 6152/9000
# Document 6153/9000
# Document 6154/9000
# Document 6155/9000
# Document 6156/9000
# Document 6157/9000
# Document 6157 has no title. Proceeding..
# Document 6159/9000
# Document 6160/9000
# Document 6161/9000
# Document 6162/9000
# Document 6163/9000
# Document 6164/9000
# Document 6165/9000
# Document 6166/9000
# Document 6167/9000
# Document 6168/9000
# Document 6169/9000
# Document 6170/9000
# Document 6171/9000
# Document 6172/9000
# Document 6173/9000
# Document 6174/9000
# Document 6175/9000
# Document 6176/9000
# Document 6177/9000
# Document 6178/9000
# Document 6179/9000
# Document 6180/9000
# Document 6181/9000
# Document 6182/9000
# Document 6183/9000
# Document 6184/9000
# Document 6185/9000
# Document 6186/9000
# Document 6187/9000
# Document 6188/9000
# Document 6189/9000
# Document 6190/9000
# Document 6191/9000
# Document 6192/9000
# Document 6193/9000
# Document 6194/9000
# Document 6195/9000
# Document 6196/9000
# Document 6197/9000
# Document 6198/9000
# Document 6199/9000
# Document 6200/9000
# Document 6201/9000
# Document 6202/9000
# Document 6203/9000
# Document 6204/9000
# Document 6205/9000
# Document 6205 has no title. Proceeding..
# Document 6207/9000
# Document 6208/9000
# Document 6209/9000
# Document 6210/9000
# Document 6211/9000
# Document 6212/9000
# Document 6212 has no title. Proceeding..
# Document 6213 has no title. Proceeding..
# Document 6215/9000
# Document 6216/9000
# Document 6217/9000
# Document 6218/9000
# Document 6219/9000
# Document 6220/9000
# Document 6221/9000
# Document 6222/9000
# Document 6223/9000
# Document 6224/9000
# Document 6224 has no title. Proceeding..
# Document 6226/9000
# Document 6227/9000
# Document 6228/9000
# Document 6229/9000
# Document 6230/9000
# Document 6231/9000
# Document 6232/9000
# Document 6233/9000
# Document 6234/9000
# Document 6235/9000
# Document 6236/9000
# Document 6237/9000
# Document 6238/9000
# Document 6239/9000
# Document 6240/9000
# Document 6241/9000
# Document 6242/9000
# Document 6242 has no title. Proceeding..
# Document 6244/9000
# Document 6245/9000
# Document 6246/9000
# Document 6247/9000
# Document 6248/9000
# Document 6249/9000
# Document 6250/9000
# Document 6251/9000
# Document 6252/9000
# Document 6253/9000
# Document 6254/9000
# Document 6255/9000
# Document 6256/9000
# Document 6257/9000
# Document 6258/9000
# Document 6259/9000
# Document 6260/9000
# Document 6261/9000
# Document 6262/9000
# No data on document 6262. Proceeding..
# Document 6264/9000
# Document 6265/9000
# Document 6266/9000
# Document 6267/9000
# Document 6268/9000
# Document 6269/9000
# Document 6270/9000
# Document 6271/9000
# Document 6272/9000
# Document 6273/9000
# Document 6274/9000
# Document 6275/9000
# Document 6276/9000
# Document 6277/9000
# Document 6278/9000
# Document 6279/9000
# Document 6280/9000
# Document 6281/9000
# Document 6282/9000
# Document 6283/9000
# Document 6284/9000
# Document 6285/9000
# Document 6286/9000
# Document 6287/9000
# Document 6288/9000
# Document 6289/9000
# Document 6290/9000
# Document 6291/9000
# Document 6292/9000
# Document 6293/9000
# Document 6294/9000
# Document 6295/9000
# Document 6296/9000
# Document 6297/9000
# Document 6298/9000
# Document 6299/9000
# Document 6300/9000
# Document 6301/9000
# Document 6302/9000
# Document 6303/9000
# Document 6304/9000
# Document 6305/9000
# Document 6305 has no title. Proceeding..
# Document 6307/9000
# Document 6308/9000
# Document 6309/9000
# Document 6310/9000
# Document 6311/9000
# Document 6312/9000
# Document 6313/9000
# Document 6314/9000
# Document 6315/9000
# Document 6316/9000
# Document 6317/9000
# Document 6318/9000
# Document 6319/9000
# Document 6320/9000
# Document 6321/9000
# Document 6322/9000
# Document 6323/9000
# Document 6324/9000
# Document 6325/9000
# Document 6326/9000
# Document 6327/9000
# Document 6328/9000
# Document 6329/9000
# Document 6330/9000
# Document 6331/9000
# Document 6332/9000
# Document 6333/9000
# Document 6334/9000
# Document 6335/9000
# Document 6336/9000
# Document 6337/9000
# Document 6338/9000
# Document 6339/9000
# Document 6340/9000
# Document 6341/9000
# Document 6342/9000
# Document 6343/9000
# Document 6344/9000
# Document 6345/9000
# Document 6346/9000
# Document 6347/9000
# Document 6348/9000
# Document 6349/9000
# Document 6350/9000
# Document 6351/9000
# Document 6352/9000
# Document 6353/9000
# Document 6354/9000
# Document 6355/9000
# Document 6356/9000
# Document 6357/9000
# Document 6358/9000
# Document 6359/9000
# Document 6360/9000
# Document 6361/9000
# Document 6362/9000
# Document 6363/9000
# Document 6364/9000
# Document 6365/9000
# Document 6366/9000
# Document 6367/9000
# Document 6368/9000
# Document 6369/9000
# Document 6370/9000
# Document 6371/9000
# Document 6372/9000
# Document 6373/9000
# Document 6374/9000
# Document 6375/9000
# Document 6376/9000
# Document 6377/9000
# Document 6378/9000
# Document 6379/9000
# Document 6380/9000
# Document 6381/9000
# Document 6382/9000
# Document 6383/9000
# Document 6384/9000
# Document 6385/9000
# Document 6386/9000
# Document 6387/9000
# Document 6388/9000
# Document 6389/9000
# Document 6390/9000
# Document 6391/9000
# Document 6392/9000
# Document 6393/9000
# Document 6394/9000
# Document 6395/9000
# Document 6396/9000
# Document 6396 has no title. Proceeding..
# Document 6398/9000
# Document 6399/9000
# Document 6400/9000
# Document 6401/9000
# Document 6402/9000
# Document 6403/9000
# Document 6404/9000
# Document 6405/9000
# Document 6406/9000
# Document 6407/9000
# Document 6407 has no title. Proceeding..
# Document 6409/9000
# Document 6410/9000
# ...
# Document 8196/9000
# Document 8197/9000
# Document 8198/9000
# Document 8198 has no title. Proceeding..
# Document 8200/9000
# Document 8201/9000
# Document 8202/9000
# Document 8203/9000
# Document 8204/9000
# Document 8205/9000
# Document 8206/9000
# Document 8207/9000
# Document 8208/9000
# Document 8209/9000
# Document 8210/9000
# Document 8211/9000
# Document 8212/9000
# Document 8213/9000
# Document 8214/9000
# Document 8215/9000
# Document 8216/9000
# Document 8217/9000
# Document 8218/9000
# Document 8219/9000
# Document 8220/9000
# Document 8221/9000
# Document 8222/9000
# Document 8223/9000
# Document 8224/9000
# Document 8225/9000
# Document 8226/9000
# Document 8227/9000
# Document 8228/9000
# Document 8229/9000
# Document 8230/9000
# Document 8231/9000
# Document 8232/9000
# Document 8233/9000
# Document 8234/9000
# Document 8235/9000
# Document 8236/9000
# Document 8237/9000
# Document 8238/9000
# Document 8239/9000
# Document 8240/9000
# Document 8241/9000
# Document 8242/9000
# Document 8243/9000
# Document 8244/9000
# Document 8245/9000
# Document 8246/9000
# Document 8247/9000
# Document 8248/9000
# Document 8249/9000
# Document 8250/9000
# Document 8251/9000
# Document 8252/9000
# Document 8253/9000
# Document 8254/9000
# Document 8255/9000
# Document 8256/9000
# Document 8257/9000
# Document 8258/9000
# Document 8259/9000
# Document 8260/9000
# Document 8261/9000
# Document 8262/9000
# Document 8263/9000
# Document 8264/9000
# Document 8265/9000
# Document 8266/9000
# Document 8267/9000
# Document 8268/9000
# Document 8269/9000
# Document 8270/9000
# Document 8271/9000
# Document 8272/9000
# Document 8273/9000
# Document 8274/9000
# Document 8275/9000
# Document 8276/9000
# Document 8277/9000
# Document 8278/9000
# Document 8279/9000
# Document 8279 has no title. Proceeding..
# Document 8281/9000
# Document 8282/9000
# Document 8283/9000
# Document 8284/9000
# Document 8285/9000
# Document 8286/9000
# Document 8287/9000
# Document 8288/9000
# Document 8289/9000
# Document 8290/9000
# Document 8291/9000
# Document 8291 has no title. Proceeding..
# Document 8293/9000
# Document 8294/9000
# Document 8295/9000
# Document 8296/9000
# Document 8297/9000
# Document 8298/9000
# Document 8299/9000
# Document 8300/9000
# Document 8301/9000
# Document 8302/9000
# Document 8303/9000
# Document 8304/9000
# Document 8305/9000
# Document 8306/9000
# Document 8307/9000
# Document 8308/9000
# Document 8309/9000
# Document 8310/9000
# Document 8311/9000
# Document 8312/9000
# Document 8313/9000
# Document 8314/9000
# Document 8315/9000
# Document 8316/9000
# Document 8317/9000
# Document 8318/9000
# Document 8319/9000
# Document 8320/9000
# Document 8321/9000
# Document 8322/9000
# Document 8322 has no title. Proceeding..
# Document 8324/9000
# Document 8325/9000
# Document 8326/9000
# Document 8327/9000
# Document 8328/9000
# Document 8329/9000
# Document 8330/9000
# Document 8331/9000
# Document 8332/9000
# Document 8333/9000
# Document 8334/9000
# Document 8335/9000
# Document 8336/9000
# Document 8337/9000
# Document 8338/9000
# Document 8339/9000
# Document 8340/9000
# Document 8341/9000
# Document 8342/9000
# Document 8343/9000
# Document 8344/9000
# Document 8345/9000
# Document 8346/9000
# Document 8347/9000
# Document 8348/9000
# Document 8349/9000
# Document 8350/9000
# Document 8351/9000
# Document 8352/9000
# Document 8353/9000
# Document 8354/9000
# Document 8355/9000
# Document 8356/9000
# Document 8357/9000
# Document 8358/9000
# Document 8359/9000
# Document 8360/9000
# Document 8361/9000
# Document 8362/9000
# Document 8363/9000
# Document 8364/9000
# Document 8365/9000
# Document 8366/9000
# Document 8367/9000
# Document 8368/9000
# Document 8369/9000
# Document 8370/9000
# Document 8370 has no title. Proceeding..
# Document 8372/9000
# Document 8373/9000
# Document 8374/9000
# Document 8375/9000
# Document 8376/9000
# Document 8377/9000
# Document 8377 has no title. Proceeding..
# Document 8378 has no title. Proceeding..
# Document 8380/9000
# Document 8381/9000
# Document 8382/9000
# Document 8383/9000
# Document 8383 has no title. Proceeding..
# Document 8385/9000
# Document 8386/9000
# Document 8387/9000
# Document 8388/9000
# Document 8389/9000
# Document 8390/9000
# Document 8391/9000
# Document 8392/9000
# Document 8393/9000
# Document 8394/9000
# Document 8395/9000
# Document 8396/9000
# Document 8397/9000
# Document 8398/9000
# Document 8399/9000
# Document 8400/9000
# Document 8401/9000
# Document 8401 has no title. Proceeding..
# Document 8403/9000
# Document 8404/9000
# Document 8405/9000
# Document 8406/9000
# Document 8407/9000
# Document 8408/9000
# Document 8409/9000
# Document 8410/9000
# Document 8411/9000
# Document 8412/9000
# Document 8413/9000
# Document 8414/9000
# Document 8415/9000
# Document 8415 has no title. Proceeding..
# Document 8417/9000
# Document 8418/9000
# Document 8419/9000
# Document 8420/9000
# Document 8421/9000
# Document 8422/9000
# Document 8423/9000
# Document 8424/9000
# Document 8425/9000
# Document 8426/9000
# Document 8427/9000
# Document 8428/9000
# Document 8429/9000
# Document 8429 has no title. Proceeding..
# Document 8431/9000
# Document 8432/9000
# Document 8433/9000
# Document 8434/9000
# Document 8435/9000
# Document 8436/9000
# Document 8437/9000
# Document 8438/9000
# Document 8439/9000
# Document 8440/9000
# Document 8441/9000
# Document 8442/9000
# Document 8443/9000
# Document 8444/9000
# Document 8445/9000
# Document 8446/9000
# Document 8447/9000
# Document 8448/9000
# Document 8449/9000
# Document 8450/9000
# Document 8451/9000
# Document 8452/9000
# Document 8453/9000
# Document 8454/9000
# Document 8455/9000
# Document 8456/9000
# Document 8457/9000
# Document 8458/9000
# Document 8459/9000
# Document 8460/9000
# Document 8461/9000
# Document 8462/9000
# Document 8463/9000
# Document 8464/9000
# Document 8465/9000
# Document 8466/9000
# Document 8467/9000
# Document 8468/9000
# Document 8469/9000
# Document 8470/9000
# Document 8471/9000
# Document 8472/9000
# Document 8473/9000
# Document 8473 has no title. Proceeding..
# Document 8475/9000
# Document 8476/9000
# Document 8477/9000
# Document 8478/9000
# Document 8479/9000
# Document 8480/9000
# Document 8481/9000
# Document 8482/9000
# Document 8483/9000
# Document 8484/9000
# Document 8485/9000
# Document 8486/9000
# Document 8486 has no title. Proceeding..
# Document 8488/9000
# Document 8489/9000
# Document 8490/9000
# Document 8491/9000
# Document 8491 has no title. Proceeding..
# Document 8493/9000
# Document 8494/9000
# Document 8495/9000
# Document 8496/9000
# Document 8497/9000
# Document 8498/9000
# Document 8499/9000
# Document 8500/9000
# Document 8501/9000
# Document 8502/9000
# Document 8503/9000
# Document 8504/9000
# Document 8505/9000
# Document 8506/9000
# Document 8507/9000
# Document 8508/9000
# Document 8509/9000
# Document 8510/9000
# Document 8511/9000
# Document 8512/9000
# Document 8512 has no title. Proceeding..
# Document 8513 has no title. Proceeding..
# Document 8515/9000
# Document 8515 has no title. Proceeding..
# Document 8517/9000
# Document 8518/9000
# Document 8519/9000
# Document 8520/9000
# Document 8521/9000
# Document 8522/9000
# Document 8523/9000
# Document 8524/9000
# Document 8525/9000
# Document 8526/9000
# Document 8526 has no title. Proceeding..
# Document 8528/9000
# Document 8529/9000
# Document 8530/9000
# Document 8531/9000
# Document 8532/9000
# Document 8533/9000
# Document 8534/9000
# Document 8535/9000
# Document 8536/9000
# Document 8537/9000
# Document 8538/9000
# Document 8539/9000
# Document 8540/9000
# Document 8541/9000
# Document 8542/9000
# Document 8543/9000
# Document 8544/9000
# Document 8545/9000
# Document 8546/9000
# Document 8547/9000
# Document 8548/9000
# Document 8549/9000
# Document 8550/9000
# Document 8551/9000
# Document 8552/9000
# Document 8553/9000
# Document 8554/9000
# Document 8555/9000
# Document 8556/9000
# Document 8557/9000
# Document 8558/9000
# Document 8559/9000
# Document 8560/9000
# Document 8561/9000
# Document 8562/9000
# Document 8563/9000
# Document 8564/9000
# Document 8565/9000
# Document 8566/9000
# Document 8567/9000
# Document 8568/9000
# Document 8569/9000
# Document 8570/9000
# Document 8571/9000
# Document 8572/9000
# Document 8573/9000
# Document 8574/9000
# Document 8575/9000
# Document 8576/9000
# Document 8577/9000
# Document 8578/9000
# Document 8579/9000
# Document 8580/9000
# Document 8581/9000
# Document 8582/9000
# Document 8583/9000
# Document 8584/9000
# Document 8585/9000
# Document 8586/9000
# Document 8587/9000
# Document 8588/9000
# Document 8589/9000
# Document 8590/9000
# Document 8591/9000
# Document 8592/9000
# Document 8593/9000
# Document 8594/9000
# Document 8594 has no title. Proceeding..
# Document 8596/9000
# Document 8597/9000
# Document 8598/9000
# Document 8599/9000
# Document 8600/9000
# Document 8601/9000
# Document 8602/9000
# Document 8603/9000
# Document 8604/9000
# Document 8605/9000
# Document 8606/9000
# Document 8607/9000
# Document 8608/9000
# Document 8609/9000
# Document 8610/9000
# Document 8611/9000
# Document 8612/9000
# Document 8613/9000
# Document 8614/9000
# Document 8614 has no title. Proceeding..
# Document 8616/9000
# Document 8617/9000
# Document 8618/9000
# Document 8619/9000
# Document 8620/9000
# Document 8621/9000
# Document 8622/9000
# Document 8623/9000
# Document 8624/9000
# Document 8625/9000
# Document 8626/9000
# Document 8627/9000
# Document 8628/9000
# Document 8629/9000
# Document 8630/9000
# Document 8631/9000
# Document 8631 has no title. Proceeding..
# Document 8633/9000
# Document 8634/9000
# Document 8635/9000
# Document 8636/9000
# Document 8637/9000
# Document 8638/9000
# Document 8639/9000
# Document 8640/9000
# Document 8641/9000
# Document 8642/9000
# Document 8643/9000
# Document 8644/9000
# Document 8645/9000
# Document 8646/9000
# Document 8647/9000
# Document 8648/9000
# Document 8649/9000
# Document 8650/9000
# Document 8651/9000
# Document 8652/9000
# Document 8652 has no title. Proceeding..
# Document 8654/9000
# Document 8655/9000
# Document 8656/9000
# Document 8657/9000
# Document 8658/9000
# Document 8659/9000
# Document 8660/9000
# Document 8661/9000
# Document 8662/9000
# Document 8663/9000
# Document 8664/9000
# Document 8665/9000
# Document 8666/9000
# Document 8667/9000
# Document 8668/9000
# Document 8669/9000
# Document 8670/9000
# Document 8671/9000
# Document 8672/9000
# Document 8673/9000
# Document 8674/9000
# Document 8675/9000
# Document 8676/9000
# Document 8677/9000
# Document 8678/9000
# Document 8679/9000
# Document 8680/9000
# Document 8681/9000
# Document 8682/9000
# Document 8683/9000
# Document 8684/9000
# Document 8685/9000
# Document 8686/9000
# Document 8687/9000
# Document 8688/9000
# Document 8689/9000
# Document 8690/9000
# Document 8691/9000
# Document 8692/9000
# Document 8693/9000
# Document 8694/9000
# Document 8695/9000
# Document 8696/9000
# Document 8697/9000
# Document 8698/9000
# Document 8699/9000
# Document 8700/9000
# Document 8701/9000
# Document 8702/9000
# Document 8703/9000
# Document 8704/9000
# Document 8705/9000
# Document 8706/9000
# Document 8707/9000
# Document 8708/9000
# Document 8709/9000
# Document 8710/9000
# Document 8711/9000
# Document 8712/9000
# Document 8713/9000
# Document 8714/9000
# Document 8715/9000
# Document 8716/9000
# Document 8717/9000
# Document 8718/9000
# Document 8719/9000
# Document 8720/9000
# Document 8721/9000
# Document 8722/9000
# Document 8723/9000
# Document 8724/9000
# Document 8725/9000
# Document 8726/9000
# Document 8727/9000
# Document 8728/9000
# Document 8729/9000
# Document 8730/9000
# Document 8731/9000
# Document 8732/9000
# Document 8732 has no title. Proceeding..
# Document 8734/9000
# Document 8735/9000
# Document 8736/9000
# Document 8737/9000
# Document 8738/9000
# Document 8739/9000
# Document 8740/9000
# Document 8741/9000
# Document 8742/9000
# Document 8743/9000
# Document 8744/9000
# Document 8745/9000
# Document 8746/9000
# Document 8747/9000
# Document 8748/9000
# Document 8749/9000
# Document 8750/9000
# Document 8751/9000
# Document 8752/9000
# Document 8753/9000
# Document 8754/9000
# Document 8755/9000
# Document 8756/9000
# Document 8757/9000
# Document 8758/9000
# Document 8759/9000
# Document 8759 has no title. Proceeding..
# Document 8761/9000
# Document 8762/9000
# Document 8763/9000
# Document 8764/9000
# Document 8765/9000
# Document 8766/9000
# Document 8767/9000
# Document 8768/9000
# Document 8769/9000
# Document 8770/9000
# Document 8771/9000
# Document 8772/9000
# Document 8773/9000
# Document 8774/9000
# Document 8775/9000
# Document 8776/9000
# Document 8777/9000
# Document 8778/9000
# Document 8779/9000
# Document 8780/9000
# Document 8780 has no title. Proceeding..
# Document 8782/9000
# Document 8783/9000
# Document 8784/9000
# Document 8785/9000
# Document 8786/9000
# Document 8787/9000
# Document 8788/9000
# Document 8789/9000
# Document 8790/9000
# Document 8791/9000
# Document 8792/9000
# Document 8793/9000
# Document 8794/9000
# Document 8795/9000
# Document 8796/9000
# Document 8797/9000
# Document 8798/9000
# Document 8799/9000
# Document 8800/9000
# Document 8801/9000
# Document 8802/9000
# Document 8803/9000
# Document 8804/9000
# Document 8805/9000
# Document 8806/9000
# Document 8807/9000
# Document 8807 has no title. Proceeding..
# Document 8809/9000
# Document 8810/9000
# Document 8811/9000
# Document 8812/9000
# Document 8813/9000
# Document 8814/9000
# Document 8815/9000
# Document 8816/9000
# Document 8817/9000
# Document 8818/9000
# Document 8819/9000
# Document 8820/9000
# Document 8820 has no title. Proceeding..
# Document 8822/9000
# Document 8823/9000
# Document 8824/9000
# Document 8825/9000
# Document 8826/9000
# Document 8827/9000
# Document 8828/9000
# Document 8829/9000
# Document 8830/9000
# Document 8831/9000
# Document 8832/9000
# Document 8833/9000
# Document 8834/9000
# Document 8835/9000
# Document 8836/9000
# Document 8837/9000
# Document 8838/9000
# Document 8839/9000
# Document 8840/9000
# Document 8840 has no title. Proceeding..
# Document 8842/9000
# Document 8843/9000
# Document 8844/9000
# Document 8845/9000
# Document 8846/9000
# Document 8847/9000
# Document 8848/9000
# Document 8849/9000
# Document 8850/9000
# Document 8851/9000
# Document 8852/9000
# Document 8853/9000
# Document 8854/9000
# Document 8855/9000
# Document 8856/9000
# Document 8857/9000
# Document 8858/9000
# Document 8859/9000
# Document 8860/9000
# Document 8861/9000
# Document 8862/9000
# Document 8863/9000
# Document 8864/9000
# Document 8865/9000
# Document 8866/9000
# Document 8867/9000
# Document 8868/9000
# Document 8869/9000
# Document 8869 has no title. Proceeding..
# Document 8871/9000
# Document 8872/9000
# Document 8873/9000
# Document 8874/9000
# Document 8875/9000
# Document 8876/9000
# Document 8877/9000
# Document 8878/9000
# Document 8879/9000
# Document 8880/9000
# Document 8881/9000
# Document 8882/9000
# Document 8883/9000
# Document 8884/9000
# Document 8885/9000
# Document 8886/9000
# Document 8887/9000
# Document 8888/9000
# Document 8889/9000
# Document 8890/9000
# Document 8891/9000
# Document 8892/9000
# Document 8893/9000
# Document 8894/9000
# Document 8895/9000
# Document 8896/9000
# Document 8897/9000
# Document 8898/9000
# Document 8899/9000
# Document 8900/9000
# Document 8901/9000
# Document 8902/9000
# Document 8903/9000
# Document 8904/9000
# Document 8905/9000
# Document 8906/9000
# Document 8907/9000
# Document 8908/9000
# Document 8909/9000
# Document 8910/9000
# Document 8911/9000
# Document 8912/9000
# Document 8913/9000
# Document 8914/9000
# Document 8915/9000
# Document 8916/9000
# Document 8917/9000
# Document 8918/9000
# Document 8919/9000
# Document 8920/9000
# Document 8921/9000
# Document 8922/9000
# Document 8923/9000
# Document 8924/9000
# Document 8925/9000
# Document 8926/9000
# Document 8927/9000
# Document 8928/9000
# Document 8928 has no title. Proceeding..
# Document 8930/9000
# Document 8931/9000
# Document 8932/9000
# Document 8933/9000
# Document 8934/9000
# Document 8935/9000
# Document 8936/9000
# Document 8937/9000
# Document 8938/9000
# Document 8939/9000
# Document 8940/9000
# Document 8941/9000
# Document 8942/9000
# Document 8943/9000
# Document 8944/9000
# Document 8945/9000
# Document 8946/9000
# Document 8947/9000
# Document 8948/9000
# Document 8949/9000
# Document 8950/9000
# Document 8951/9000
# Document 8952/9000
# Document 8953/9000
# Document 8954/9000
# Document 8955/9000
# Document 8956/9000
# Document 8957/9000
# Document 8958/9000
# Document 8959/9000
# Document 8960/9000
# Document 8961/9000
# Document 8962/9000
# Document 8963/9000
# Document 8964/9000
# Document 8965/9000
# Document 8966/9000
# Document 8967/9000
# Document 8968/9000
# Document 8969/9000
# Document 8970/9000
# Document 8971/9000
# Document 8972/9000
# Document 8973/9000
# Document 8974/9000
# Document 8975/9000
# Document 8976/9000
# Document 8977/9000
# Document 8978/9000
# Document 8979/9000
# Document 8980/9000
# Document 8981/9000
# Document 8982/9000
# Document 8983/9000
# Document 8984/9000
# Document 8985/9000
# Document 8986/9000
# Document 8987/9000
# Document 8988/9000
# Document 8989/9000
# Document 8990/9000
# Document 8991/9000
# Document 8992/9000
# Document 8993/9000
# Document 8994/9000
# Document 8995/9000
# Document 8996/9000
# Document 8997/9000
# Document 8998/9000
# Document 8998 has no title. Proceeding..
# Document 9000/9000
# Elapsed time: 31m 26s

# %%
for idx, question in enumerate(questions):
  print(f'Question: {question}')
  print(f'From paper with title: {titles[idx]}')
  print(f'Passage answer: {answers[idx]}')
  print(f'Score: {scores[idx]:.2f}\n')
# Out:
# Question: What are the coronaviruses?
# From paper with title: Alignment-free method for DNA sequence clustering using Fuzzy integral similarity
# Passage answer: The coronaviruses are pleomorphic RNA viruses that are widespread among avians, bats, humans and other mammals.
# Score: 85.51
#
# Question: What was discovered in Wuhuan in December 2019?
# From paper with title: Clinical Medicine Characteristics of and Public Health Responses to the Coronavirus Disease 2019 Outbreak in China
# Passage answer: In December 2019In December 2019, a cluster of pneumonia of unknown etiology was detected in Wuhan City, Hubei Province of China.
# Score: 79.24
#
# Question: What is Coronovirus Disease 2019?
# From paper with title: Comment
# Passage answer: The ongoing coronavirus disease 2019 (COVID-19) outbreak is giving rise to worldwide anxieties, rumours, and online misinformation.
# Score: 79.98
#
# Question: What is COVID-19?
# From paper with title: Consensus statement The species Severe acute respiratory syndrome- related coronavirus: classifying 2019-nCoV and naming it SARS-CoV-2 Coronaviridae Study Group of the International Committee on Taxonomy of Viruses*
# Passage answer: The present outbreak of a coronavirus-associated acute respiratory disease called coronavirus disease 19 (COVID-19) is the third documented spillover of an animal coronavirus to humans in only two decades that has resulted in a major epidemic.
# Score: 84.65
#
# Question: What is caused by SARS-COV2?
# From paper with title: SARS-Coronavirus Open Reading Frame-3a drives multimodal necrotic cell death
# Passage answer: In summary, Rip3-mediated oligomerization of SARS 3a causes necrotic cell death, lysosomal damage, and caspase-1 activation-all likely contributing to the clinical manifestations of SARS-CoV infection.Severe acute respiratory syndrome (SARS) is caused by a coronavirus (SARS-CoV) that at its peak affected more than 8000 people with a 10% mortality rate 1 .
# Score: 82.65
#
# Question: How is COVID-19 spread?
# From paper with title: viruses Perspective Potential Maternal and Infant Outcomes from Coronavirus 2019-nCoV (SARS-CoV-2) Infecting Pregnant Women: Lessons from SARS, MERS, and Other Human Coronavirus Infections
# Passage answer: This newly recognized coronavirus, producing a disease that has been termed COVID-19, is rapidly spreading throughout China, has crossed international borders to infect persons in neighboring countries, and humans infected by the virus are travelling via commercial airlines to other continents.
# Score: 85.82
#
# Question: Where was COVID-19 discovered?
# From paper with title: Clinical Medicine Optimization Method for Forecasting Confirmed Cases of COVID-19 in China
# Passage answer: In December 2019, a novel coronavirus, called COVID-19, was discovered in Wuhan, China, and has spread to different cities in China as well as to 24 other countries.
# Score: 85.02
#
# Question: How many deaths were caused by COVID-19?
# From paper with title: Systematic Comparison of Two Animal-to-Human Transmitted Human Coronaviruses: SARS-CoV-2 and SARS-CoV
# Passage answer: According to the latest data on Feb. 14th, 2020 [55, 56] , there have been a total of 67,081 clinically diagnosed cases of COVID-19 in worldwide, with 1,526 deaths.
# Score: 87.31
#
# Question: Does wearing a mask prevent the spread of COVID-19?
# From paper with title: Estimated effectiveness of symptom and risk screening to prevent the spread of COVID-19
# Passage answer: These findings can support evidence-based policy to combat the spread of COVID-19, and prospective planning to mitigate future emerging pathogens.
# Score: 89.28

# %% [markdown]
# ### **Evaluate answers ✅**
#
# Let's talk about the answers we got after running the model `multi-qa-mpnet-base-dot-v1` for the whole dataset (9000 documents) which took 1 hour on the Tesla P100 GPU. All models produce fairly good results with each having its own questions that are best answered. I provide the results for each of the models in the `results.pdf` file (in the current directory) and compare the performance of the models based on some metrics.

# %% [markdown]
# **Question:** What are the coronaviruses?
# **From paper with title:** Natural Bis-Benzylisoquinoline Alkaloids-Tetrandrine, Fangchinoline, and Cepharanthine, Inhibit Human Coronavirus OC43 Infection of MRC-5 Human Lung Cells
# **Passage answer:** Coronaviruses (CoVs) are enveloped, positive-sense, single-stranded RNA viruses that infect a broad range of animal species and cause multiple respiratory outcomes of varying severity, including the common cold, bronchiolitis, and pneumonia [13].
#
# **Comments:** It's a very good answer. Just what we wanted.
#
# ---
#
# **Question:** What was discovered in Wuhuan in December 2019?
# **From paper with title:** Identification of a Novel Polyomavirus from Patients with Acute Respiratory Tract Infections
# **Passage answer:** This discovery raises many questions for further investigation, such as, Is WU virus a human pathogen?
#
# **Comments:** Relevant answer. It doesn't answer our question though.
#
# ---
#
# **Question:** What is Coronovirus Disease 2019?
# **From paper with title:** Systematic Comparison of Two Animal-to-Human Transmitted Human Coronaviruses: SARS-CoV-2 and SARS-CoV
# **Passage answer:** This virus causes acute lung symptoms, leading to a condition that has been named as "coronavirus disease 2019" (COVID-19).
#
# **Comments:** It's a fine answer. Answers our question.
#
# ---
#
# **Question:** What is COVID-19?
# **From paper with title:** Systematic Comparison of Two Animal-to-Human Transmitted Human Coronaviruses: SARS-CoV-2 and SARS-CoV.
# **Passage answer:** This virus causes acute lung symptoms, leading to a condition that has been named as "coronavirus disease 2019" (COVID-19).
#
# **Comments:** It's a good answer. Answers our question.
#
# ---
#
# **Question:** What is caused by SARS-COV2?
# **From paper with title:** Viral Mimicry to Usurp Ubiquitin and SUMO Host Pathways
# **Passage answer:** SARS CoV is the causative agent for severe acute respiratory syndrome, which frequently leads to outbreaks and high mortality.
#
# **Comments:** It's a very good answer. Answers our question.
#
# ---
#
# **Question:** How is COVID-19 spread?
# **From paper with title:** Rapid communication
# **Passage answer:** The outbreak has spread rapidly, affecting other parts of China, and cases have been recorded on several continents (Asia, Australia, Europe and North America); further global spread is likely to occur [4] .The spectrum of this disease in humans, now named coronavirus disease 2019 (COVID-19) [5] , is yet to be fully determined.
#
# **Comments:** Related answer. We cannot say that it answers our question as we wanted it to but at the time the dataset was published such information may not have been available as it is stated in the text that "The spectrum of this disease in humans, now named coronavirus disease 2019 (COVID-19) [5] , *is yet to be fully determined.*"
#
# ---
#
# **Question:** Where was COVID-19 discovered?
# **From paper with title:** Clinical Medicine Optimization Method for Forecasting Confirmed Cases of COVID-19 in China
# **Passage answer:** In December 2019, a novel coronavirus, called COVID-19, was discovered in Wuhan, China, and has spread to different cities in China as well as to 24 other countries.
#
# **Comments:** It's a very good answer. Just what we wanted.
#
# ---
#
# **Question:** How many deaths were caused by COVID-19?
# **From paper with title:** Identification of COVID-19 Can be Quicker through Artificial Intelligence framework using a Mobile Phone-Based Survey in the Populations when Cities/Towns Are Under Quarantine
# **Passage answer:** As of February 25 th 2020, the World Health Organization's situational data indicates that there were about 77780 confirmed cases, including 2666 deaths due to COVID-19, including cases in 25 countries [4] .
#
# **Comments:** Very good answer. Just what we wanted.
#
# ---
#
# **Question:** Does wearing a mask prevent the spread of COVID-19?
# **From paper with title:** Transmission of Influenza A in a Student Office Based on Realistic Person-to-Person Contact and Surface Touch Behaviour
# **Passage answer:** Wearing a mask can control the spread of disease via the long-range airborne, fomite and close contact routes.
#
# **Comments:** Very good answer. Just what we wanted.

# %% [markdown]
# ### **Search a question 🧐**
#
# I have modified the *search function* in order to ask the system for just a single question.

# %%
def search_a_question(model, question, N_SAMPLES = None):
  best_score = -100 
  best_titles = '' 
  best_answers = ''

  if N_SAMPLES != None:
    sample = jsons_data.sample(n=N_SAMPLES, random_state=123)
  else:
    sample = jsons_data

  print(f'Running the `{model_names[model]}` for {len(sample.index)} documents\n')
  
  question_embeddings = model.encode(question)
  MAX_SEQ_LEN = model_max_seq_len[model]

  start_time = time.time()
  counter = 0
  for index, row in sample.iterrows():
    counter += 1
    abstract_sentences = row['abstract']
    text_sentences = row['text']
    data = abstract_sentences + text_sentences
    data = clean_data(data, MAX_SEQ_LEN)

    if not row['title']:
      print(f'Document {counter-1} has no title. Proceeding..')
      continue
    if not data:
      print(f'No data on document {counter-1}. Proceeding..')
      continue

    data_embeddings = model.encode(data)

    scores = util.dot_score(question_embeddings, data_embeddings)[0].cpu().tolist()

    # Combine docs & scores
    doc_score_pairs = list(zip(data, scores))

    # Sort by decreasing score
    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)

    score = doc_score_pairs[0][1]
    answer = doc_score_pairs[0][0]

    if score > best_score:
      best_score = score
      best_title = row['title']
      best_answer = answer
            
    print(f'Document {counter}/{len(sample.index)}')
      
  end_time = time.time()
  elapsed_time = end_time - start_time
  elapsed_mins = int(elapsed_time / 60)
  elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
  print(f'Elapsed time: {elapsed_mins}m {elapsed_secs}s')

  return best_score, best_title, best_answer

# %%
question = 'What are the symptoms of COVID-19?'

score, title, answer = search_a_question(model_1, question, N_SAMPLES=150)
# Out:
# Running the `multi-qa-mpnet-base-dot-v1` for 150 documents
#
# Document 1/150
# Document 2/150
# Document 3/150
# Document 3 has no title. Proceeding..
# Document 5/150
# Document 6/150
# Document 7/150
# Document 8/150
# Document 9/150
# Document 10/150
# Document 11/150
# Document 12/150
# Document 13/150
# Document 14/150
# Document 15/150
# Document 16/150
# Document 17/150
# Document 18/150
# Document 19/150
# Document 20/150
# Document 21/150
# Document 22/150
# Document 23/150
# Document 24/150
# Document 25/150
# Document 25 has no title. Proceeding..
# Document 27/150
# Document 28/150
# Document 29/150
# Document 30/150
# Document 31/150
# Document 32/150
# Document 33/150
# Document 34/150
# Document 35/150
# Document 35 has no title. Proceeding..
# Document 37/150
# Document 38/150
# Document 39/150
# Document 40/150
# Document 41/150
# Document 42/150
# Document 43/150
# Document 44/150
# Document 45/150
# Document 46/150
# Document 47/150
# Document 48/150
# Document 49/150
# Document 50/150
# Document 51/150
# Document 52/150
# Document 53/150
# Document 54/150
# Document 55/150
# Document 56/150
# Document 57/150
# Document 58/150
# Document 59/150
# Document 60/150
# Document 61/150
# Document 62/150
# Document 63/150
# Document 64/150
# Document 65/150
# Document 66/150
# Document 67/150
# Document 68/150
# Document 69/150
# Document 70/150
# Document 71/150
# Document 72/150
# Document 73/150
# Document 74/150
# Document 75/150
# Document 75 has no title. Proceeding..
# Document 77/150
# Document 78/150
# Document 79/150
# Document 80/150
# Document 81/150
# Document 82/150
# Document 83/150
# Document 84/150
# Document 85/150
# Document 86/150
# Document 87/150
# Document 88/150
# Document 89/150
# Document 90/150
# Document 91/150
# Document 92/150
# Document 93/150
# Document 94/150
# Document 95/150
# Document 96/150
# Document 97/150
# Document 98/150
# Document 99/150
# Document 99 has no title. Proceeding..
# Document 101/150
# Document 102/150
# Document 103/150
# Document 104/150
# Document 105/150
# Document 106/150
# Document 107/150
# Document 108/150
# Document 109/150
# Document 110/150
# Document 111/150
# Document 112/150
# Document 113/150
# Document 113 has no title. Proceeding..
# Document 115/150
# Document 116/150
# Document 117/150
# Document 118/150
# Document 119/150
# Document 120/150
# Document 121/150
# Document 122/150
# Document 123/150
# Document 124/150
# Document 125/150
# Document 126/150
# Document 127/150
# Document 128/150
# Document 129/150
# Document 130/150
# Document 131/150
# Document 132/150
# Document 133/150
# Document 134/150
# Document 134 has no title. Proceeding..
# Document 136/150
# Document 137/150
# Document 138/150
# Document 139/150
# Document 140/150
# Document 141/150
# Document 142/150
# Document 143/150
# Document 144/150
# Document 145/150
# Document 146/150
# Document 147/150
# Document 148/150
# Document 149/150
# Document 150/150
# Elapsed time: 0m 57s

# %%
print(f'Question: {question}')
print(f'From paper with title: {title}')
print(f'Passage answer: {answer}')
print(f'Score: {score:.2f}\n')
# Out:
# Question: What are the symptoms of COVID-19?
# From paper with title: The history and epidemiology of Middle East respiratory syndrome corona virus
# Passage answer: The clinical presentation of MERS-CoV ranges from flu-like symptoms, i.e., fever and cough in 87% of patients, chills, rigor, rhinorrhea, myalgia, and fatigue, to more severe symptoms, including shortness of breath in 48% of patients and respiratory failure, resulting in the requirement for intubation and ventilation.
# Score: 23.52

# %% [markdown]
# ### **Thoughts 💭**
#
# The answers above come after using the `multi-qa-mpnet-base-dot-v1` for embedding the whole dataset (9000 scientific articles) and using the `dot_score` for calculating the similarity of each sentence with each question posed. We can see that all answers are relevant to the related question and almost all of them are pretty good while they actually answer their question!
#
# **Technical details:**
# * **Model used:** From SBERT, Pretrained Models, the `multi-qa-mpnet-base-dot-v1`
# * **Run time:** 1 hour on the Tesla P100 GPU. On the GPU T8, the runtime is four times as long, about 4 hours. For this reason, I have set the `N_SAMPLES` parameter in the search function to specify a subset of randomly selected documents from the dataset to limit the search there. You can see that by setting `N_SAMPLES = 500`, which also gives pretty good results in short amount of time!
# * **Similarity check function:** [`util.dot_score`](https://www.sbert.net/docs/package_reference/util.html#sentence_transformers.util.dot_score) from sentence transformers library, which calculates the dot product between each embedded sentence and each embedded question.
#
# **Can we do any better?**
#
# I think we can. A very important parameter to consider is the way the similarity score is calculated. Given two sentences (in our case a question and a possible answer) the model does not understand the meanings of either the question or the answer. It simply tries to match as closely as possible any two sentences and hopes that this will be the best answer. But this is not the case in many cases. Take for example the question `"What are the coronaviruses?"`. If I didn't take only sentences at least 10 words long, my model would give the answer: coronaviruses. Yes, obviously coronaviruses are coronaviruses, but we are asking for a more detailed explanation of what a coronavirus is, which the model cannot understand. So, I think if we find a more intelligent way of calculating the similarity score we can get better results.
#
# **Something kind of weird:** When running the model using `N_SAMPLES = 500` we get much better answers for some queries than when running the model for the whole dataset. Perhaps this is because the model selects as the best answer the sentence that seems (according to the sentence embeddings) the most similar to the question. This means that the model cannot understand the conceptual meaning of the question but tries to find sentences as "close" as possible to the question. As we can see, this produces poor results for some questions.
#
# Overall, I would say that the model produces pretty good answers and at no case any irrelevant ones.
